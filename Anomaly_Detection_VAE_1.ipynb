# %% [markdown]
# # Anomaly Detection with Variational Autoencoders and Encoded Cluster Plots

# %% [markdown]
# This is my work for constructing and testing a Variational Autoencoder (VAE) that helps detect Alzheimer's Disease early using images from three linked conditions.

# %% [markdown]
# First, I did all relevant imports for this project and seeded everything.

# %%
## All Imports ##
import os
import random
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.notebook import tqdm
from sklearn.manifold import TSNE
import pandas as pd
from PIL import Image

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, Subset
from torchvision.datasets import ImageFolder
from torchvision import transforms

def set_seed(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    np.random.seed(seed)
    random.seed(seed)

set_seed(0)

train_set_pct = 1.0

# %% [markdown]
# Next, I mounted my google drive, where I unzipped all files downloaded in my local drive. All data was obtained from the article "Identifying Medical Diagnoses and Treatable Diseases by Image-Based Deep Learning" published in the journal Cell.
#
# Citation for Data Usage:
# Kermany D, Goldbaum M, Cai W et al. Identifying Medical Diagnoses and Treatable Diseases by Image-Based Deep Learning. Cell. 2018; 172(5):1122-1131. doi:10.1016/j.cell.2018.02.010.

# %%
#MOUNTING THE DRIVE
from google.colab import drive
drive.mount('/content/drive')

# !rsync -ah -progress "/content/drive/MyDrive/Colab Notebooks/Kermany Data/ZhangLabData.zip" "/content"
# !unzip /content/ZhangLabData.zip

PATH_TRAIN = "/content/CellData/OCT/train"
PATH_TEST = "/content/CellData/OCT/test"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: CellData/OCT/train/DME/DME-778975-125.jpeg
#   inflating: CellData/OCT/train/DME/DME-258763-26.jpeg
#   inflating: CellData/OCT/train/DME/DME-8457431-23.jpeg
#   inflating: CellData/OCT/train/DME/DME-3304080-55.jpeg
#   inflating: CellData/OCT/train/DME/DME-5006393-70.jpeg
#   inflating: CellData/OCT/train/DME/DME-5091309-15.jpeg
#   inflating: CellData/OCT/train/DME/DME-3064922-181.jpeg
#   inflating: CellData/OCT/train/DME/DME-8525575-184.jpeg
#   inflating: CellData/OCT/train/DME/DME-5143281-26.jpeg
#   inflating: CellData/OCT/train/DME/DME-6737988-35.jpeg
#   inflating: CellData/OCT/train/DME/DME-3064922-202.jpeg
#   inflating: CellData/OCT/train/DME/DME-3531101-20.jpeg
#   inflating: CellData/OCT/train/DME/DME-3157783-58.jpeg
#   inflating: CellData/OCT/train/DME/DME-258763-41.jpeg
#   inflating: CellData/OCT/train/DME/DME-30521-85.jpeg
#   inflating: CellData/OCT/train/DME/DME-5489583-15.jpeg
#   inflating: CellData/OCT/train/DME/DME-3340309-24.jpeg
#   inflating: CellData/OCT/train/DME/DME-4428613-1.jpeg
#   inflating: CellData/OCT/train/DME/DME-4732091-37.jpeg
#   inflating: CellData/OCT/train/DME/DME-633268-14.jpeg
#   inflating: CellData/OCT/train/DME/DME-4242335-121.jpeg
#   inflating: CellData/OCT/train/DME/DME-3712405-18.jpeg
#   inflating: CellData/OCT/train/DME/DME-3606968-2.jpeg
#   inflating: CellData/OCT/train/DME/DME-5006393-43.jpeg
#   inflating: CellData/OCT/train/DME/DME-5656004-24.jpeg
#   inflating: CellData/OCT/train/DME/DME-5497895-61.jpeg
#   inflating: CellData/OCT/train/DME/DME-5459995-3.jpeg
#   inflating: CellData/OCT/train/DME/DME-3064922-29.jpeg
#   inflating: CellData/OCT/train/DME/DME-8681418-5.jpeg
#   inflating: CellData/OCT/train/DME/DME-8457431-17.jpeg
#   inflating: CellData/OCT/train/DME/DME-4634094-109.jpeg
#   inflating: CellData/OCT/train/DME/DME-5178244-7.jpeg
#   inflating: CellData/OCT/train/DME/DME-4428613-4.jpeg
#   inflating: CellData/OCT/train/DME/DME-5313093-25.jpeg
#   inflating: CellData/OCT/train/DME/DME-2630113-19.jpeg
#   inflating: CellData/OCT/train/DME/DME-1649492-9.jpeg
#   inflating: CellData/OCT/train/DME/DME-7585263-37.jpeg
#   inflating: CellData/OCT/train/DME/DME-778975-88.jpeg
#   inflating: CellData/OCT/train/DME/DME-8021831-25.jpeg
#   inflating: CellData/OCT/train/DME/DME-8525575-117.jpeg
#   inflating: CellData/OCT/train/DME/DME-5006393-9.jpeg
#   inflating: CellData/OCT/train/DME/DME-8602716-112.jpeg
#   inflating: CellData/OCT/train/DME/DME-8177380-34.jpeg
#   inflating: CellData/OCT/train/DME/DME-7763916-99.jpeg
#   inflating: CellData/OCT/train/DME/DME-778975-8.jpeg
#   inflating: CellData/OCT/train/DME/DME-4119721-52.jpeg
#   inflating: CellData/OCT/train/DME/DME-6914545-8.jpeg
#   inflating: CellData/OCT/train/DME/DME-4892276-3.jpeg
#   inflating: CellData/OCT/train/DME/DME-9729147-6.jpeg
#   inflating: CellData/OCT/train/DME/DME-9853958-6.jpeg
#   inflating: CellData/OCT/train/DME/DME-8253827-6.jpeg
#   inflating: CellData/OCT/train/DME/DME-4494007-3.jpeg
#   inflating: CellData/OCT/train/DME/DME-2630113-47.jpeg
#   inflating: CellData/OCT/train/DME/DME-462675-40.jpeg
#   inflating: CellData/OCT/train/DME/DME-4772167-2.jpeg
#   inflating: CellData/OCT/train/DME/DME-4269147-12.jpeg
#   inflating: CellData/OCT/train/DME/DME-462675-53.jpeg
#   inflating: CellData/OCT/train/DME/DME-9915316-40.jpeg
#   inflating: CellData/OCT/train/DME/DME-9615869-2.jpeg
#   inflating: CellData/OCT/train/DME/DME-7750274-5.jpeg
#   inflating: CellData/OCT/train/DME/DME-6884821-53.jpeg
#   inflating: CellData/OCT/train/DME/DME-1808783-21.jpeg
#   inflating: CellData/OCT/train/DME/DME-4732091-33.jpeg
#   inflating: CellData/OCT/train/DME/DME-7707202-20.jpeg
#   inflating: CellData/OCT/train/DME/DME-9678611-2.jpeg
#   inflating: CellData/OCT/train/DME/DME-9540117-3.jpeg
#   inflating: CellData/OCT/train/DME/DME-7578162-25.jpeg
#   inflating: CellData/OCT/train/DME/DME-7918201-29.jpeg
#   inflating: CellData/OCT/train/DME/DME-8019418-24.jpeg
#   inflating: CellData/OCT/train/DME/DME-4445075-51.jpeg
#   inflating: CellData/OCT/train/DME/DME-1860310-2.jpeg
#   inflating: CellData/OCT/train/DME/DME-3712405-59.jpeg
#   inflating: CellData/OCT/train/DME/DME-7870558-3.jpeg
#   inflating: CellData/OCT/train/DME/DME-3473531-4.jpeg
#   inflating: CellData/OCT/train/DME/DME-3712405-7.jpeg
#   inflating: CellData/OCT/train/DME/DME-7972888-5.jpeg
#   inflating: CellData/OCT/train/DME/DME-3491563-2.jpeg
#   inflating: CellData/OCT/train/DME/DME-633268-70.jpeg
#   inflating: CellData/OCT/train/DME/DME-30521-106.jpeg
#   inflating: CellData/OCT/train/DME/DME-8889771-20.jpeg
#   inflating: CellData/OCT/train/DME/DME-4897748-61.jpeg
#   inflating: CellData/OCT/train/DME/DME-4432202-6.jpeg
#   inflating: CellData/OCT/train/DME/DME-1649492-63.jpeg
#   inflating: CellData/OCT/train/DME/DME-4432202-32.jpeg
#   inflating: CellData/OCT/train/DME/DME-5489583-22.jpeg
#   inflating: CellData/OCT/train/DME/DME-778975-131.jpeg
#   inflating: CellData/OCT/train/DME/DME-5434248-24.jpeg
#   inflating: CellData/OCT/train/DME/DME-1163718-1.jpeg
#   inflating: CellData/OCT/train/DME/DME-3114569-12.jpeg
#   inflating: CellData/OCT/train/DME/DME-4244491-3.jpeg
#   inflating: CellData/OCT/train/DME/DME-8019418-67.jpeg
#   inflating: CellData/OCT/train/DME/DME-3473531-1.jpeg
#   inflating: CellData/OCT/train/DME/DME-4634094-135.jpeg
#   inflating: CellData/OCT/train/DME/DME-9931747-3.jpeg
#   inflating: CellData/OCT/train/DME/DME-82328-2.jpeg
#   inflating: CellData/OCT/train/DME/DME-9815862-12.jpeg
#   inflating: CellData/OCT/train/DME/DME-4732091-73.jpeg
#   inflating: CellData/OCT/train/DME/DME-4693151-6.jpeg
#   inflating: CellData/OCT/train/DME/DME-5656004-31.jpeg
#   inflating: CellData/OCT/train/DME/DME-4643364-48.jpeg
#   inflating: CellData/OCT/train/DME/DME-3064922-58.jpeg
#   inflating: CellData/OCT/train/DME/DME-3114569-7.jpeg
#   inflating: CellData/OCT/train/DME/DME-5549735-2.jpeg
#   inflating: CellData/OCT/train/DME/DME-214825-3.jpeg
#   inflating: CellData/OCT/train/DME/DME-9915316-48.jpeg
#   inflating: CellData/OCT/train/DME/DME-8231523-5.jpeg
#   inflating: CellData/OCT/train/DME/DME-30521-60.jpeg
#   inflating: CellData/OCT/train/DME/DME-5014129-6.jpeg
#   inflating: CellData/OCT/train/DME/DME-119840-24.jpeg
#   inflating: CellData/OCT/train/DME/DME-7700504-7.jpeg
#   inflating: CellData/OCT/train/DME/DME-4967228-47.jpeg
#   inflating: CellData/OCT/train/DME/DME-778975-38.jpeg
#   inflating: CellData/OCT/train/DME/DME-4430279-7.jpeg
#   inflating: CellData/OCT/train/DME/DME-4967228-24.jpeg
#   inflating: CellData/OCT/train/DME/DME-3340309-16.jpeg
#   inflating: CellData/OCT/train/DME/DME-3546221-7.jpeg
#   inflating: CellData/OCT/train/DME/DME-3441556-31.jpeg
#   inflating: CellData/OCT/train/DME/DME-3542808-61.jpeg
#   inflating: CellData/OCT/train/DME/DME-8555080-14.jpeg
#   inflating: CellData/OCT/train/DME/DME-7578162-5.jpeg
#   inflating: CellData/OCT/train/DME/DME-1629753-9.jpeg
#   inflating: CellData/OCT/train/DME/DME-2493975-3.jpeg
#   inflating: CellData/OCT/train/DME/DME-8766603-4.jpeg
#   inflating: CellData/OCT/train/DME/DME-8087608-2.jpeg
#   inflating: CellData/OCT/train/DME/DME-1695472-6.jpeg
#   inflating: CellData/OCT/train/DME/DME-3358004-11.jpeg
#   inflating: CellData/OCT/train/DME/DME-5006393-4.jpeg
#   inflating: CellData/OCT/train/DME/DME-7837305-67.jpeg
#   inflating: CellData/OCT/train/DME/DME-269181-22.jpeg
#   inflating: CellData/OCT/train/DME/DME-4732091-66.jpeg
#   inflating: CellData/OCT/train/DME/DME-4468878-9.jpeg
#   inflating: CellData/OCT/train/DME/DME-7700504-4.jpeg
#   inflating: CellData/OCT/train/DME/DME-9361825-6.jpeg
#   inflating: CellData/OCT/train/DME/DME-9721607-18.jpeg
#   inflating: CellData/OCT/train/DME/DME-5313093-48.jpeg
#   inflating: CellData/OCT/train/DME/DME-8177380-9.jpeg
#   inflating: CellData/OCT/train/DME/DME-2780638-9.jpeg
#   inflating: CellData/OCT/train/DME/DME-4445075-136.jpeg
#   inflating: CellData/OCT/train/DME/DME-9939654-35.jpeg
#   inflating: CellData/OCT/train/DME/DME-8457431-52.jpeg
#   inflating: CellData/OCT/train/DME/DME-6798210-66.jpeg
#   inflating: CellData/OCT/train/DME/DME-3064922-127.jpeg
#   inflating: CellData/OCT/train/DME/DME-8469406-7.jpeg
#   inflating: CellData/OCT/train/DME/DME-8602716-76.jpeg
#   inflating: CellData/OCT/train/DME/DME-8021831-23.jpeg
#   inflating: CellData/OCT/train/DME/DME-4242335-132.jpeg
#   inflating: CellData/OCT/train/DME/DME-3757443-77.jpeg
#   inflating: CellData/OCT/train/DME/DME-1591159-65.jpeg
#   inflating: CellData/OCT/train/DME/DME-7918201-21.jpeg
#   inflating: CellData/OCT/train/DME/DME-8560276-59.jpeg
#   inflating: CellData/OCT/train/DME/DME-7763916-112.jpeg
#   inflating: CellData/OCT/train/DME/DME-3757443-44.jpeg
#   inflating: CellData/OCT/train/DME/DME-328450-1.jpeg
#   inflating: CellData/OCT/train/DME/DME-3472166-5.jpeg
#   inflating: CellData/OCT/train/DME/DME-4634094-64.jpeg
#   inflating: CellData/OCT/train/DME/DME-4242335-230.jpeg
#   inflating: CellData/OCT/train/DME/DME-4468878-3.jpeg
#   inflating: CellData/OCT/train/DME/DME-5669621-11.jpeg
#   inflating: CellData/OCT/train/DME/DME-5171738-43.jpeg
#   inflating: CellData/OCT/train/DME/DME-5225805-40.jpeg
#   inflating: CellData/OCT/train/DME/DME-5178244-35.jpeg
#   inflating: CellData/OCT/train/DME/DME-3712405-72.jpeg
#   inflating: CellData/OCT/train/DME/DME-462675-18.jpeg
#   inflating: CellData/OCT/train/DME/DME-3157783-22.jpeg
#   inflating: CellData/OCT/train/DME/DME-30521-48.jpeg
#   inflating: CellData/OCT/train/DME/DME-8732456-37.jpeg
#   inflating: CellData/OCT/train/DME/DME-3534474-1.jpeg
#   inflating: CellData/OCT/train/DME/DME-3064922-136.jpeg
#   inflating: CellData/OCT/train/DME/DME-8021831-28.jpeg
#   inflating: CellData/OCT/train/DME/DME-8907654-11.jpeg
#   inflating: CellData/OCT/train/DME/DME-5091309-9.jpeg
#   inflating: CellData/OCT/train/DME/DME-4585256-2.jpeg
#   inflating: CellData/OCT/train/DME/DME-8589279-1.jpeg
#   inflating: CellData/OCT/train/DME/DME-3608465-40.jpeg
#   inflating: CellData/OCT/train/DME/DME-9583225-47.jpeg
#   inflating: CellData/OCT/train/DME/DME-4658666-49.jpeg
#   inflating: CellData/OCT/train/DME/DME-3757443-94.jpeg
#   inflating: CellData/OCT/train/DME/DME-4897748-39.jpeg
#   inflating: CellData/OCT/train/DME/DME-3441556-93.jpeg
#   inflating: CellData/OCT/train/DME/DME-4732091-1.jpeg
#   inflating: CellData/OCT/train/DME/DME-8889771-5.jpeg
#   inflating: CellData/OCT/train/DME/DME-8525575-107.jpeg
#   inflating: CellData/OCT/train/DME/DME-4242335-125.jpeg
#   inflating: CellData/OCT/train/DME/DME-402066-13.jpeg
#   inflating: CellData/OCT/train/DME/DME-4634094-142.jpeg
#   inflating: CellData/OCT/train/DME/DME-8861620-5.jpeg
#   inflating: CellData/OCT/train/DME/DME-4242335-90.jpeg
#   inflating: CellData/OCT/train/DME/DME-5449404-6.jpeg
#   inflating: CellData/OCT/train/DME/DME-4643364-23.jpeg
#   inflating: CellData/OCT/train/DME/DME-6716735-2.jpeg
#   inflating: CellData/OCT/train/DME/DME-8525575-47.jpeg
#   inflating: CellData/OCT/train/DME/DME-8647070-4.jpeg
#   inflating: CellData/OCT/train/DME/DME-3757443-32.jpeg
#   inflating: CellData/OCT/train/DME/DME-5000180-3.jpeg
#   inflating: CellData/OCT/train/DME/DME-4940184-6.jpeg
#   inflating: CellData/OCT/train/DME/DME-9721607-75.jpeg
#   inflating: CellData/OCT/train/DME/DME-6914545-9.jpeg
#   inflating: CellData/OCT/train/DME/DME-9812420-14.jpeg
#   inflating: CellData/OCT/train/DME/DME-6716735-8.jpeg
#   inflating: CellData/OCT/train/DME/DME-4897748-3.jpeg
#   inflating: CellData/OCT/train/DME/DME-9126005-24.jpeg
#   inflating: CellData/OCT/train/DME/DME-2630113-20.jpeg
#   inflating: CellData/OCT/train/DME/DME-582495-1.jpeg
#   inflating: CellData/OCT/train/DME/DME-7928636-6.jpeg
#   inflating: CellData/OCT/train/DME/DME-3064922-206.jpeg
#   inflating: CellData/OCT/train/DME/DME-5178244-3.jpeg
#   inflating: CellData/OCT/train/DME/DME-5178244-14.jpeg
#   inflating: CellData/OCT/train/DME/DME-4030787-89.jpeg
#   inflating: CellData/OCT/train/DME/DME-8797076-2.jpeg
#   inflating: CellData/OCT/train/DME/DME-6884821-49.jpeg
#   inflating: CellData/OCT/train/DME/DME-5006393-15.jpeg
#   inflating: CellData/OCT/train/DME/DME-4484249-4.jpeg
#   inflating: CellData/OCT/train/DME/DME-8019418-21.jpeg
#   inflating: CellData/OCT/train/DME/DME-8889771-42.jpeg
#   inflating: CellData/OCT/train/DME/DME-8602716-58.jpeg
#   inflating: CellData/OCT/train/DME/DME-9721607-68.jpeg
#   inflating: CellData/OCT/train/DME/DME-2063196-2.jpeg
#   inflating: CellData/OCT/train/DME/DME-7618102-2.jpeg
#   inflating: CellData/OCT/train/DME/DME-5178244-5.jpeg
#   inflating: CellData/OCT/train/DME/DME-4445075-69.jpeg
#   inflating: CellData/OCT/train/DME/DME-5497895-34.jpeg
#   inflating: CellData/OCT/train/DME/DME-8602716-2.jpeg
#   inflating: CellData/OCT/train/DME/DME-7614088-27.jpeg
#   inflating: CellData/OCT/train/DME/DME-2205167-27.jpeg
#   inflating: CellData/OCT/train/DME/DME-5313366-1.jpeg
#   inflating: CellData/OCT/train/DME/DME-5469051-4.jpeg
#   inflating: CellData/OCT/train/DME/DME-1591159-85.jpeg
#   inflating: CellData/OCT/train/DME/DME-4652865-2.jpeg
#   inflating: CellData/OCT/train/DME/DME-8021831-31.jpeg
#   inflating: CellData/OCT/train/DME/DME-8200056-10.jpeg
#   inflating: CellData/OCT/train/DME/DME-3276918-17.jpeg
#   inflating: CellData/OCT/train/DME/DME-5223925-15.jpeg
#   inflating: CellData/OCT/train/DME/DME-4567079-1.jpeg
#   inflating: CellData/OCT/train/DME/DME-8457431-11.jpeg
#   inflating: CellData/OCT/train/DME/DME-4445075-41.jpeg
#   inflating: CellData/OCT/train/DME/DME-4445075-30.jpeg
#   inflating: CellData/OCT/train/DME/DME-9720453-6.jpeg
#   inflating: CellData/OCT/train/DME/DME-4969104-18.jpeg
#   inflating: CellData/OCT/train/DME/DME-8193815-12.jpeg
#   inflating: CellData/OCT/train/DME/DME-7591008-1.jpeg
#   inflating: CellData/OCT/train/DME/DME-8889771-11.jpeg
#   inflating: CellData/OCT/train/DME/DME-3064922-43.jpeg
#   inflating: CellData/OCT/train/DME/DME-4969104-27.jpeg
#   inflating: CellData/OCT/train/DME/DME-306172-88.jpeg
#   inflating: CellData/OCT/train/DME/DME-8560276-6.jpeg
#   inflating: CellData/OCT/train/DME/DME-6593270-1.jpeg
#   inflating: CellData/OCT/train/DME/DME-956743-2.jpeg
#   inflating: CellData/OCT/train/DME/DME-3340309-18.jpeg
#   inflating: CellData/OCT/train/DME/DME-2506710-3.jpeg
#   inflating: CellData/OCT/train/DME/DME-6798210-25.jpeg
#   inflating: CellData/OCT/train/DME/DME-3346049-11.jpeg
#   inflating: CellData/OCT/train/DME/DME-4697954-5.jpeg
#   inflating: CellData/OCT/train/DME/DME-8426419-22.jpeg
#   inflating: CellData/OCT/train/DME/DME-843382-10.jpeg
#   inflating: CellData/OCT/train/DME/DME-7658334-4.jpeg
#   inflating: CellData/OCT/train/DME/DME-7646640-1.jpeg
#   inflating: CellData/OCT/train/DME/DME-6878052-2.jpeg
#   inflating: CellData/OCT/train/DME/DME-7585263-19.jpeg
#   inflating: CellData/OCT/train/DME/DME-2205167-8.jpeg
#   inflating: CellData/OCT/train/DME/DME-3064922-216.jpeg
#   inflating: CellData/OCT/train/DME/DME-8525575-173.jpeg
#   inflating: CellData/OCT/train/DME/DME-5072525-7.jpeg
#   inflating: CellData/OCT/train/DME/DME-778975-13.jpeg
#   inflating: CellData/OCT/train/DME/DME-4630435-38.jpeg
#   inflating: CellData/OCT/train/DME/DME-7837305-5.jpeg
#   inflating: CellData/OCT/train/DME/DME-4030787-63.jpeg
#   inflating: CellData/OCT/train/DME/DME-7763916-101.jpeg
#   inflating: CellData/OCT/train/DME/DME-5091309-16.jpeg
#   inflating: CellData/OCT/train/DME/DME-5449404-7.jpeg
#   inflating: CellData/OCT/train/DME/DME-323904-2.jpeg
#   inflating: CellData/OCT/train/DME/DME-3542808-56.jpeg
#   inflating: CellData/OCT/train/DME/DME-5006393-68.jpeg
#   inflating: CellData/OCT/train/DME/DME-8487067-10.jpeg
#   inflating: CellData/OCT/train/DME/DME-8889771-46.jpeg
#   inflating: CellData/OCT/train/DME/DME-5313093-31.jpeg
#   inflating: CellData/OCT/train/DME/DME-9836152-8.jpeg
#   inflating: CellData/OCT/train/DME/DME-3064922-73.jpeg
#   inflating: CellData/OCT/train/DME/DME-9932957-2.jpeg
#   inflating: CellData/OCT/train/DME/DME-7763916-123.jpeg
#   inflating: CellData/OCT/train/DME/DME-3327045-6.jpeg
#   inflating: CellData/OCT/train/DME/DME-2205167-18.jpeg
#   inflating: CellData/OCT/train/DME/DME-3513297-6.jpeg
#   inflating: CellData/OCT/train/DME/DME-3464701-8.jpeg
#   inflating: CellData/OCT/train/DME/DME-306172-66.jpeg
#   inflating: CellData/OCT/train/DME/DME-4242335-82.jpeg
#   inflating: CellData/OCT/train/DME/DME-8525575-92.jpeg
#   inflating: CellData/OCT/train/DME/DME-119840-17.jpeg
#   inflating: CellData/OCT/train/DME/DME-4430279-6.jpeg
#   inflating: CellData/OCT/train/DME/DME-9660862-4.jpeg
#   inflating: CellData/OCT/train/DME/DME-30521-63.jpeg
#   inflating: CellData/OCT/train/DME/DME-8990488-6.jpeg
#   inflating: CellData/OCT/train/DME/DME-4432202-10.jpeg
#   inflating: CellData/OCT/train/DME/DME-4643364-41.jpeg
#   inflating: CellData/OCT/train/DME/DME-8019418-33.jpeg
#   inflating: CellData/OCT/train/DME/DME-3157783-87.jpeg
#   inflating: CellData/OCT/train/DME/DME-3441556-57.jpeg
#   inflating: CellData/OCT/train/DME/DME-4732091-23.jpeg
#   inflating: CellData/OCT/train/DME/DME-7763916-2.jpeg
#   inflating: CellData/OCT/train/DME/DME-8602716-95.jpeg
#   inflating: CellData/OCT/train/DME/DME-9812420-16.jpeg
#   inflating: CellData/OCT/train/DME/DME-8021831-20.jpeg
#   inflating: CellData/OCT/train/DME/DME-6354157-8.jpeg
#   inflating: CellData/OCT/train/DME/DME-4731487-4.jpeg
#   inflating: CellData/OCT/train/DME/DME-1591159-56.jpeg
#   inflating: CellData/OCT/train/DME/DME-4336607-25.jpeg
#   inflating: CellData/OCT/train/DME/DME-9915316-70.jpeg
#   inflating: CellData/OCT/train/DME/DME-4904794-28.jpeg
#   inflating: CellData/OCT/train/DME/DME-4697954-7.jpeg
#   inflating: CellData/OCT/train/DME/DME-4897748-62.jpeg
#   inflating: CellData/OCT/train/DME/DME-462675-46.jpeg
#   inflating: CellData/OCT/train/DME/DME-3327045-5.jpeg
#   inflating: CellData/OCT/train/DME/DME-8019418-28.jpeg
#   inflating: CellData/OCT/train/DME/DME-670450-15.jpeg
#   inflating: CellData/OCT/train/DME/DME-3441556-68.jpeg
#   inflating: CellData/OCT/train/DME/DME-3718895-9.jpeg
#   inflating: CellData/OCT/train/DME/DME-9836152-5.jpeg
#   inflating: CellData/OCT/train/DME/DME-8560276-19.jpeg
#   inflating: CellData/OCT/train/DME/DME-8889771-24.jpeg
#   inflating: CellData/OCT/train/DME/DME-4967228-21.jpeg
#   inflating: CellData/OCT/train/DME/DME-3064922-68.jpeg
#   inflating: CellData/OCT/train/DME/DME-8729675-62.jpeg
#   inflating: CellData/OCT/train/DME/DME-8602716-38.jpeg
#   inflating: CellData/OCT/train/DME/DME-8019418-9.jpeg
#   inflating: CellData/OCT/train/DME/DME-3064922-94.jpeg
#   inflating: CellData/OCT/train/DME/DME-6354157-7.jpeg
#   inflating: CellData/OCT/train/DME/DME-3414068-9.jpeg
#   inflating: CellData/OCT/train/DME/DME-7950284-12.jpeg
#   inflating: CellData/OCT/train/DME/DME-7598038-6.jpeg
#   inflating: CellData/OCT/train/DME/DME-5656004-21.jpeg
#   inflating: CellData/OCT/train/DME/DME-7750274-6.jpeg
#   inflating: CellData/OCT/train/DME/DME-5223925-4.jpeg
#   inflating: CellData/OCT/train/DME/DME-5178244-30.jpeg
#   inflating: CellData/OCT/train/DME/DME-4561631-14.jpeg
#   inflating: CellData/OCT/train/DME/DME-778975-87.jpeg
#   inflating: CellData/OCT/train/DME/DME-5922512-1.jpeg
#   inflating: CellData/OCT/train/DME/DME-8426419-7.jpeg
#   inflating: CellData/OCT/train/DME/DME-5497895-42.jpeg
#   inflating: CellData/OCT/train/DME/DME-8599136-9.jpeg
#   inflating: CellData/OCT/train/DME/DME-9815862-11.jpeg
#   inflating: CellData/OCT/train/DME/DME-8734429-7.jpeg
#   inflating: CellData/OCT/train/DME/DME-633268-39.jpeg
#   inflating: CellData/OCT/train/DME/DME-8525575-81.jpeg
#   inflating: CellData/OCT/train/DME/DME-9915316-99.jpeg
#   inflating: CellData/OCT/train/DME/DME-8021831-22.jpeg
#   inflating: CellData/OCT/train/DME/DME-8615417-3.jpeg
#   inflating: CellData/OCT/train/DME/DME-8177380-30.jpeg
#   inflating: CellData/OCT/train/DME/DME-9721607-93.jpeg
#   inflating: CellData/OCT/train/DME/DME-9588051-15.jpeg
#   inflating: CellData/OCT/train/DME/DME-633268-8.jpeg
#   inflating: CellData/OCT/train/DME/DME-9812420-11.jpeg
#   inflating: CellData/OCT/train/DME/DME-30521-205.jpeg
#   inflating: CellData/OCT/train/DME/DME-5465575-28.jpeg
#   inflating: CellData/OCT/train/DME/DME-3565572-2.jpeg
#   inflating: CellData/OCT/train/DME/DME-4255624-5.jpeg
#   inflating: CellData/OCT/train/DME/DME-6884821-29.jpeg
#   inflating: CellData/OCT/train/DME/DME-8889771-56.jpeg
#   inflating: CellData/OCT/train/DME/DME-3441556-82.jpeg
#   inflating: CellData/OCT/train/DME/DME-5178244-29.jpeg
#   inflating: CellData/OCT/train/DME/DME-5223925-24.jpeg
#   inflating: CellData/OCT/train/DME/DME-8525575-20.jpeg
#   inflating: CellData/OCT/train/DME/DME-4630435-70.jpeg
#   inflating: CellData/OCT/train/DME/DME-6704343-14.jpeg
#   inflating: CellData/OCT/train/DME/DME-1591159-31.jpeg
#   inflating: CellData/OCT/train/DME/DME-6695669-1.jpeg
#   inflating: CellData/OCT/train/DME/DME-2261889-7.jpeg
#   inflating: CellData/OCT/train/DME/DME-4478609-4.jpeg
#   inflating: CellData/OCT/train/DME/DME-956743-3.jpeg
#   inflating: CellData/OCT/train/DME/DME-5951745-2.jpeg
#   inflating: CellData/OCT/train/DME/DME-5607266-8.jpeg
#   inflating: CellData/OCT/train/DME/DME-4792882-71.jpeg
#   inflating: CellData/OCT/train/DME/DME-8560276-44.jpeg
#   inflating: CellData/OCT/train/DME/DME-9853060-3.jpeg
#   inflating: CellData/OCT/train/DME/DME-6763172-5.jpeg
#   inflating: CellData/OCT/train/DME/DME-3441556-90.jpeg
#   inflating: CellData/OCT/train/DME/DME-6716735-26.jpeg
#   inflating: CellData/OCT/train/DME/DME-8889771-21.jpeg
#   inflating: CellData/OCT/train/DME/DME-4030787-87.jpeg
#   inflating: CellData/OCT/train/DME/DME-9655949-1.jpeg
#   inflating: CellData/OCT/train/DME/DME-5656004-28.jpeg
#   inflating: CellData/OCT/train/DME/DME-7638333-10.jpeg
#   inflating: CellData/OCT/train/DME/DME-8080050-13.jpeg
#   inflating: CellData/OCT/train/DME/DME-1635931-4.jpeg
#   inflating: CellData/OCT/train/DME/DME-1591159-24.jpeg
#   inflating: CellData/OCT/train/DME/DME-4240465-9.jpeg
#   inflating: CellData/OCT/train/DME/DME-8923368-4.jpeg
#   inflating: CellData/OCT/train/DME/DME-9915316-83.jpeg
#   inflating: CellData/OCT/train/DME/DME-1695472-21.jpeg
#   inflating: CellData/OCT/train/DME/DME-6707428-7.jpeg
#   inflating: CellData/OCT/train/DME/DME-778975-104.jpeg
#   inflating: CellData/OCT/train/DME/DME-3064922-26.jpeg
#   inflating: CellData/OCT/train/DME/DME-3441556-36.jpeg
#   inflating: CellData/OCT/train/DME/DME-2630113-50.jpeg
#   inflating: CellData/OCT/train/DME/DME-3483651-11.jpeg
#   inflating: CellData/OCT/train/DME/DME-8949824-4.jpeg
#   inflating: CellData/OCT/train/DME/DME-9915316-142.jpeg
#   inflating: CellData/OCT/train/DME/DME-5178244-21.jpeg
#   inflating: CellData/OCT/train/DME/DME-3441556-116.jpeg
#   inflating: CellData/OCT/train/DME/DME-8366524-7.jpeg
#   inflating: CellData/OCT/train/DME/DME-8193815-1.jpeg
#   inflating: CellData/OCT/train/DME/DME-6737988-26.jpeg
#   inflating: CellData/OCT/train/DME/DME-8729675-40.jpeg
#   inflating: CellData/OCT/train/DME/DME-3718895-37.jpeg
#   inflating: CellData/OCT/train/DME/DME-9782509-4.jpeg
#   inflating: CellData/OCT/train/DME/DME-3441556-91.jpeg
#   inflating: CellData/OCT/train/DME/DME-4445075-1.jpeg
#   inflating: CellData/OCT/train/DME/DME-3546221-5.jpeg
#   inflating: CellData/OCT/train/DME/DME-6778225-10.jpeg
#   inflating: CellData/OCT/train/DME/DME-744709-2.jpeg
#   inflating: CellData/OCT/train/DME/DME-8602716-98.jpeg
#   inflating: CellData/OCT/train/DME/DME-9729147-1.jpeg
#   inflating: CellData/OCT/train/DME/DME-258763-67.jpeg
#   inflating: CellData/OCT/train/DME/DME-514187-5.jpeg
#   inflating: CellData/OCT/train/DME/DME-1750744-5.jpeg
#   inflating: CellData/OCT/train/DME/DME-4020729-11.jpeg
#   inflating: CellData/OCT/train/DME/DME-462675-27.jpeg
#   inflating: CellData/OCT/train/DME/DME-8986387-2.jpeg
#   inflating: CellData/OCT/train/DME/DME-4242335-33.jpeg
#   inflating: CellData/OCT/train/DME/DME-2261889-20.jpeg
#   inflating: CellData/OCT/train/DME/DME-8869683-52.jpeg
#   inflating: CellData/OCT/train/DME/DME-7763916-30.jpeg
#   inflating: CellData/OCT/train/DME/DME-5339384-7.jpeg
#   inflating: CellData/OCT/train/DME/DME-285896-1.jpeg
#   inflating: CellData/OCT/train/DME/DME-7578162-57.jpeg
#   inflating: CellData/OCT/train/DME/DME-4244491-17.jpeg
#   inflating: CellData/OCT/train/DME/DME-7972888-4.jpeg
#   inflating: CellData/OCT/train/DME/DME-3064922-96.jpeg
#   inflating: CellData/OCT/train/DME/DME-1649492-30.jpeg
#   inflating: CellData/OCT/train/DME/DME-4030787-98.jpeg
#   inflating: CellData/OCT/train/DME/DME-8371885-9.jpeg
#   inflating: CellData/OCT/train/DME/DME-4242335-40.jpeg
#   inflating: CellData/OCT/train/DME/DME-8193815-17.jpeg
#   inflating: CellData/OCT/train/DME/DME-4967228-5.jpeg
#   inflating: CellData/OCT/train/DME/DME-8684044-12.jpeg
#   inflating: CellData/OCT/train/DME/DME-5091309-26.jpeg
#   inflating: CellData/OCT/train/DME/DME-1858286-3.jpeg
#   inflating: CellData/OCT/train/DME/DME-4030787-96.jpeg
#   inflating: CellData/OCT/train/DME/DME-4897748-73.jpeg
#   inflating: CellData/OCT/train/DME/DME-8167779-1.jpeg
#   inflating: CellData/OCT/train/DME/DME-7674707-1.jpeg
#   inflating: CellData/OCT/train/DME/DME-7736035-2.jpeg
#   inflating: CellData/OCT/train/DME/DME-9997680-1.jpeg
#   inflating: CellData/OCT/train/DME/DME-1695472-67.jpeg
#   inflating: CellData/OCT/train/DME/DME-8706857-3.jpeg
#   inflating: CellData/OCT/train/DME/DME-30521-71.jpeg
#   inflating: CellData/OCT/train/DME/DME-8647070-61.jpeg
#   inflating: CellData/OCT/train/DME/DME-30521-10.jpeg
#   inflating: CellData/OCT/train/DME/DME-3157783-40.jpeg
#   inflating: CellData/OCT/train/DME/DME-5669621-23.jpeg
#   inflating: CellData/OCT/train/DME/DME-4897748-20.jpeg
#   inflating: CellData/OCT/train/DME/DME-8019418-48.jpeg
#   inflating: CellData/OCT/train/DME/DME-1608084-9.jpeg
#   inflating: CellData/OCT/train/DME/DME-3718895-33.jpeg
#   inflating: CellData/OCT/train/DME/DME-4792882-32.jpeg
#   inflating: CellData/OCT/train/DME/DME-4643364-14.jpeg
#   inflating: CellData/OCT/train/DME/DME-3606968-18.jpeg
#   inflating: CellData/OCT/train/DME/DME-778975-34.jpeg
#   inflating: CellData/OCT/train/DME/DME-8177380-28.jpeg
#   inflating: CellData/OCT/train/DME/DME-4644847-5.jpeg
#   inflating: CellData/OCT/train/DME/DME-3358004-8.jpeg
#   inflating: CellData/OCT/train/DME/DME-5006393-41.jpeg
#   inflating: CellData/OCT/train/DME/DME-9721607-3.jpeg
#   inflating: CellData/OCT/train/DME/DME-9961073-3.jpeg
#   inflating: CellData/OCT/train/DME/DME-8602716-122.jpeg
#   inflating: CellData/OCT/train/DME/DME-3441556-77.jpeg
#   inflating: CellData/OCT/train/DME/DME-4732091-6.jpeg
#   inflating: CellData/OCT/train/DME/DME-4634094-66.jpeg
#   inflating: CellData/OCT/train/DME/DME-6884821-43.jpeg
#   inflating: CellData/OCT/train/DME/DME-633268-21.jpeg
#   inflating: CellData/OCT/train/DME/DME-4030787-10.jpeg
#   inflating: CellData/OCT/train/DME/DME-1702663-9.jpeg
#   inflating: CellData/OCT/train/DME/DME-258763-93.jpeg
#   inflating: CellData/OCT/train/DME/DME-262460-2.jpeg
#   inflating: CellData/OCT/train/DME/DME-8469406-1.jpeg
#   inflating: CellData/OCT/train/DME/DME-4269147-11.jpeg
#   inflating: CellData/OCT/train/DME/DME-1695472-24.jpeg
#   inflating: CellData/OCT/train/DME/DME-3542808-51.jpeg
#   inflating: CellData/OCT/train/DME/DME-3358004-4.jpeg
#   inflating: CellData/OCT/train/DME/DME-4858969-1.jpeg
#   inflating: CellData/OCT/train/DME/DME-5497895-2.jpeg
#   inflating: CellData/OCT/train/DME/DME-3608465-13.jpeg
#   inflating: CellData/OCT/train/DME/DME-7639883-1.jpeg
#   inflating: CellData/OCT/train/DME/DME-1888479-28.jpeg
#   inflating: CellData/OCT/train/DME/DME-2817912-5.jpeg
#   inflating: CellData/OCT/train/DME/DME-8130267-13.jpeg
#   inflating: CellData/OCT/train/DME/DME-9358447-1.jpeg
#   inflating: CellData/OCT/train/DME/DME-8087608-1.jpeg
#   inflating: CellData/OCT/train/DME/DME-729635-1.jpeg
#   inflating: CellData/OCT/train/DME/DME-4432202-44.jpeg
#   inflating: CellData/OCT/train/DME/DME-4007891-13.jpeg
#   inflating: CellData/OCT/train/DME/DME-9853060-20.jpeg
#   inflating: CellData/OCT/train/DME/DME-5178244-8.jpeg
#   inflating: CellData/OCT/train/DME/DME-7972888-12.jpeg
#   inflating: CellData/OCT/train/DME/DME-306172-72.jpeg
#   inflating: CellData/OCT/train/DME/DME-2232211-11.jpeg
#   inflating: CellData/OCT/train/DME/DME-6716735-77.jpeg
#   inflating: CellData/OCT/train/DME/DME-4242335-137.jpeg
#   inflating: CellData/OCT/train/DME/DME-2630113-36.jpeg
#   inflating: CellData/OCT/train/DME/DME-7680244-2.jpeg
#   inflating: CellData/OCT/train/DME/DME-8457431-35.jpeg
#   inflating: CellData/OCT/train/DME/DME-8838274-4.jpeg
#   inflating: CellData/OCT/train/DME/DME-5006393-72.jpeg
#   inflating: CellData/OCT/train/DME/DME-4607356-8.jpeg
#   inflating: CellData/OCT/train/DME/DME-682285-35.jpeg
#   inflating: CellData/OCT/train/DME/DME-8647070-29.jpeg
#   inflating: CellData/OCT/train/DME/DME-8599136-2.jpeg
#   inflating: CellData/OCT/train/DME/DME-4792882-34.jpeg
#   inflating: CellData/OCT/train/DME/DME-4445075-108.jpeg
#   inflating: CellData/OCT/train/DME/DME-9915316-114.jpeg
#   inflating: CellData/OCT/train/DME/DME-8457431-54.jpeg
#   inflating: CellData/OCT/train/DME/DME-8647070-58.jpeg
#   inflating: CellData/OCT/train/DME/DME-8349990-4.jpeg
#   inflating: CellData/OCT/train/DME/DME-8889771-14.jpeg
#   inflating: CellData/OCT/train/DME/DME-4242335-206.jpeg
#   inflating: CellData/OCT/train/DME/DME-8525575-153.jpeg
#   inflating: CellData/OCT/train/DME/DME-7638333-4.jpeg
#   inflating: CellData/OCT/train/DME/DME-8525575-1.jpeg
#   inflating: CellData/OCT/train/DME/DME-3064922-182.jpeg
#   inflating: CellData/OCT/train/DME/DME-9588051-22.jpeg
#   inflating: CellData/OCT/train/DME/DME-8457431-16.jpeg
#   inflating: CellData/OCT/train/DME/DME-306172-98.jpeg
#   inflating: CellData/OCT/train/DME/DME-1695472-4.jpeg
#   inflating: CellData/OCT/train/DME/DME-8602716-130.jpeg
#   inflating: CellData/OCT/train/DME/DME-4884451-6.jpeg
#   inflating: CellData/OCT/train/DME/DME-3441556-52.jpeg
#   inflating: CellData/OCT/train/DME/DME-8687246-1.jpeg
#   inflating: CellData/OCT/train/DME/DME-3064922-17.jpeg
#   inflating: CellData/OCT/train/DME/DME-3441556-94.jpeg
#   inflating: CellData/OCT/train/DME/DME-7585263-12.jpeg
#   inflating: CellData/OCT/train/DME/DME-6716735-76.jpeg
#   inflating: CellData/OCT/train/DME/DME-5418199-2.jpeg
#   inflating: CellData/OCT/train/DME/DME-5497895-9.jpeg
#   inflating: CellData/OCT/train/DME/DME-5572449-13.jpeg
#   inflating: CellData/OCT/train/DME/DME-8602716-11.jpeg
#   inflating: CellData/OCT/train/DME/DME-5086150-26.jpeg
#   inflating: CellData/OCT/train/DME/DME-30521-67.jpeg
#   inflating: CellData/OCT/train/DME/DME-7972888-7.jpeg
#   inflating: CellData/OCT/train/DME/DME-1695472-23.jpeg
#   inflating: CellData/OCT/train/DME/DME-4432202-41.jpeg
#   inflating: CellData/OCT/train/DME/DME-8193815-4.jpeg
#   inflating: CellData/OCT/train/DME/DME-7763916-6.jpeg
#   inflating: CellData/OCT/train/DME/DME-1591159-26.jpeg
#   inflating: CellData/OCT/train/DME/DME-3608465-38.jpeg
#   inflating: CellData/OCT/train/DME/DME-3157783-1.jpeg
#   inflating: CellData/OCT/train/DME/DME-8766603-3.jpeg
#   inflating: CellData/OCT/train/DME/DME-1743445-5.jpeg
#   inflating: CellData/OCT/train/DME/DME-30521-6.jpeg
#   inflating: CellData/OCT/train/DME/DME-7860515-13.jpeg
#   inflating: CellData/OCT/train/DME/DME-4119721-27.jpeg
#   inflating: CellData/OCT/train/DME/DME-4643364-4.jpeg
#   inflating: CellData/OCT/train/DME/DME-4432202-17.jpeg
#   inflating: CellData/OCT/train/DME/DME-4445075-112.jpeg
#   inflating: CellData/OCT/train/DME/DME-6884821-11.jpeg
#   inflating: CellData/OCT/train/DME/DME-8019418-10.jpeg
#   inflating: CellData/OCT/train/DME/DME-8525575-98.jpeg
#   inflating: CellData/OCT/train/DME/DME-2817912-16.jpeg
#   inflating: CellData/OCT/train/DME/DME-462675-31.jpeg
#   inflating: CellData/OCT/train/DME/DME-3531101-41.jpeg
#   inflating: CellData/OCT/train/DME/DME-4402311-1.jpeg
#   inflating: CellData/OCT/train/DME/DME-8692039-2.jpeg
#   inflating: CellData/OCT/train/DME/DME-4428613-7.jpeg
#   inflating: CellData/OCT/train/DME/DME-8525575-133.jpeg
#   inflating: CellData/OCT/train/DME/DME-2346350-1.jpeg
#   inflating: CellData/OCT/train/DME/DME-9504297-7.jpeg
#   inflating: CellData/OCT/train/DME/DME-778975-57.jpeg
#   inflating: CellData/OCT/train/DME/DME-778975-82.jpeg
#   inflating: CellData/OCT/train/DME/DME-4732091-62.jpeg
#   inflating: CellData/OCT/train/DME/DME-8713938-7.jpeg
#   inflating: CellData/OCT/train/DME/DME-4634094-10.jpeg
#   inflating: CellData/OCT/train/DME/DME-3064922-184.jpeg
#   inflating: CellData/OCT/train/DME/DME-1591159-81.jpeg
#   inflating: CellData/OCT/train/DME/DME-8426419-21.jpeg
#   inflating: CellData/OCT/train/DME/DME-8889771-73.jpeg
#   inflating: CellData/OCT/train/DME/DME-7928636-15.jpeg
#   inflating: CellData/OCT/train/DME/DME-30521-43.jpeg
#   inflating: CellData/OCT/train/DME/DME-4623999-6.jpeg
#   inflating: CellData/OCT/train/DME/DME-4921138-23.jpeg
#   inflating: CellData/OCT/train/DME/DME-8602716-34.jpeg
#   inflating: CellData/OCT/train/DME/DME-5000180-6.jpeg
#   inflating: CellData/OCT/train/DME/DME-8635355-2.jpeg
#   inflating: CellData/OCT/train/DME/DME-3157783-27.jpeg
#   inflating: CellData/OCT/train/DME/DME-6716735-81.jpeg
#   inflating: CellData/OCT/train/DME/DME-9126005-3.jpeg
#   inflating: CellData/OCT/train/DME/DME-7917652-10.jpeg
#   inflating: CellData/OCT/train/DME/DME-8681418-10.jpeg
#   inflating: CellData/OCT/train/DME/DME-8869683-49.jpeg
#   inflating: CellData/OCT/train/DME/DME-778975-109.jpeg
#   inflating: CellData/OCT/train/DME/DME-4242335-211.jpeg
#   inflating: CellData/OCT/train/DME/DME-4819732-7.jpeg
#   inflating: CellData/OCT/train/DME/DME-1591159-21.jpeg
#   inflating: CellData/OCT/train/DME/DME-3064922-107.jpeg
#   inflating: CellData/OCT/train/DME/DME-9915316-139.jpeg
#   inflating: CellData/OCT/train/DME/DME-8266663-2.jpeg
#   inflating: CellData/OCT/train/DME/DME-4634094-139.jpeg
#   inflating: CellData/OCT/train/DME/DME-8019418-74.jpeg
#   inflating: CellData/OCT/train/DME/DME-7434518-6.jpeg
#   inflating: CellData/OCT/train/DME/DME-8769362-3.jpeg
#   inflating: CellData/OCT/train/DME/DME-408201-10.jpeg
#   inflating: CellData/OCT/train/DME/DME-8699233-24.jpeg
#   inflating: CellData/OCT/train/DME/DME-4376118-7.jpeg
#   inflating: CellData/OCT/train/DME/DME-3157783-4.jpeg
#   inflating: CellData/OCT/train/DME/DME-8123126-2.jpeg
#   inflating: CellData/OCT/train/DME/DME-5313093-14.jpeg
#   inflating: CellData/OCT/train/DME/DME-7972888-14.jpeg
#   inflating: CellData/OCT/train/DME/DME-6884821-48.jpeg
#   inflating: CellData/OCT/train/DME/DME-3712405-78.jpeg
#   inflating: CellData/OCT/train/DME/DME-8019418-6.jpeg
#   inflating: CellData/OCT/train/DME/DME-5000180-7.jpeg
#   inflating: CellData/OCT/train/DME/DME-8647070-49.jpeg
#   inflating: CellData/OCT/train/DME/DME-5292894-5.jpeg
#   inflating: CellData/OCT/train/DME/DME-3276918-16.jpeg
#   inflating: CellData/OCT/train/DME/DME-3064922-108.jpeg
#   inflating: CellData/OCT/train/DME/DME-9815862-2.jpeg
#   inflating: CellData/OCT/train/DME/DME-1923563-3.jpeg
#   inflating: CellData/OCT/train/DME/DME-3346049-10.jpeg
#   inflating: CellData/OCT/train/DME/DME-6716735-17.jpeg
#   inflating: CellData/OCT/train/DME/DME-4240465-34.jpeg
#   inflating: CellData/OCT/train/DME/DME-4432202-22.jpeg
#   inflating: CellData/OCT/train/DME/DME-5037557-1.jpeg
#   inflating: CellData/OCT/train/DME/DME-3757443-13.jpeg
#   inflating: CellData/OCT/train/DME/DME-3304080-38.jpeg
#   inflating: CellData/OCT/train/DME/DME-8111718-1.jpeg
#   inflating: CellData/OCT/train/DME/DME-9583225-50.jpeg
#   inflating: CellData/OCT/train/DME/DME-9836152-25.jpeg
#   inflating: CellData/OCT/train/DME/DME-4445075-105.jpeg
#   inflating: CellData/OCT/train/DME/DME-4336607-61.jpeg
#   inflating: CellData/OCT/train/DME/DME-30521-75.jpeg
#   inflating: CellData/OCT/train/DME/DME-633268-47.jpeg
#   inflating: CellData/OCT/train/DME/DME-5497895-45.jpeg
#   inflating: CellData/OCT/train/DME/DME-8869683-31.jpeg
#   inflating: CellData/OCT/train/DME/DME-3064922-91.jpeg
#   inflating: CellData/OCT/train/DME/DME-7721841-1.jpeg
#   inflating: CellData/OCT/train/DME/DME-7846574-39.jpeg
#   inflating: CellData/OCT/train/DME/DME-5465575-26.jpeg
#   inflating: CellData/OCT/train/DME/DME-7846574-2.jpeg
#   inflating: CellData/OCT/train/DME/DME-3414068-15.jpeg
#   inflating: CellData/OCT/train/DME/DME-7846574-40.jpeg
#   inflating: CellData/OCT/train/DME/DME-9656462-7.jpeg
#   inflating: CellData/OCT/train/DME/DME-4973751-19.jpeg
#   inflating: CellData/OCT/train/DME/DME-3509367-3.jpeg
#   inflating: CellData/OCT/train/DME/DME-3718895-25.jpeg
#   inflating: CellData/OCT/train/DME/DME-5149443-1.jpeg
#   inflating: CellData/OCT/train/DME/DME-1591159-50.jpeg
#   inflating: CellData/OCT/train/DME/DME-5497895-18.jpeg
#   inflating: CellData/OCT/train/DME/DME-8676532-4.jpeg
#   inflating: CellData/OCT/train/DME/DME-5313093-78.jpeg
#   inflating: CellData/OCT/train/DME/DME-4969932-2.jpeg
#   inflating: CellData/OCT/train/DME/DME-6884821-52.jpeg
#   inflating: CellData/OCT/train/DME/DME-3757443-26.jpeg
#   inflating: CellData/OCT/train/DME/DME-682285-15.jpeg
#   inflating: CellData/OCT/train/DME/DME-9583225-38.jpeg
#   inflating: CellData/OCT/train/DME/DME-4644847-2.jpeg
#   inflating: CellData/OCT/train/DME/DME-269181-20.jpeg
#   inflating: CellData/OCT/train/DME/DME-1695472-64.jpeg
#   inflating: CellData/OCT/train/DME/DME-3064922-20.jpeg
#   inflating: CellData/OCT/train/DME/DME-7599844-3.jpeg
#   inflating: CellData/OCT/train/DME/DME-3064922-21.jpeg
#   inflating: CellData/OCT/train/DME/DME-7846574-29.jpeg
#   inflating: CellData/OCT/train/DME/DME-8231523-7.jpeg
#   inflating: CellData/OCT/train/DME/DME-8457431-8.jpeg
#   inflating: CellData/OCT/train/DME/DME-4630435-75.jpeg
#   inflating: CellData/OCT/train/DME/DME-306172-15.jpeg
#   inflating: CellData/OCT/train/DME/DME-4892276-2.jpeg
#   inflating: CellData/OCT/train/DME/DME-7918201-20.jpeg
#   inflating: CellData/OCT/train/DME/DME-3441556-88.jpeg
#   inflating: CellData/OCT/train/DME/DME-9583225-48.jpeg
#   inflating: CellData/OCT/train/DME/DME-3064922-211.jpeg
#   inflating: CellData/OCT/train/DME/DME-3340309-7.jpeg
#   inflating: CellData/OCT/train/DME/DME-4819732-5.jpeg
#   inflating: CellData/OCT/train/DME/DME-4585256-3.jpeg
#   inflating: CellData/OCT/train/DME/DME-6716735-79.jpeg
#   inflating: CellData/OCT/train/DME/DME-5171738-9.jpeg
#   inflating: CellData/OCT/train/DME/DME-8457431-57.jpeg
#   inflating: CellData/OCT/train/DME/DME-3882196-1.jpeg
#   inflating: CellData/OCT/train/DME/DME-5434248-18.jpeg
#   inflating: CellData/OCT/train/DME/DME-4030787-78.jpeg
#   inflating: CellData/OCT/train/DME/DME-2205167-2.jpeg
#   inflating: CellData/OCT/train/DME/DME-8788274-10.jpeg
#   inflating: CellData/OCT/train/DME/DME-4445075-34.jpeg
#   inflating: CellData/OCT/train/DME/DME-8218042-18.jpeg
#   inflating: CellData/OCT/train/DME/DME-3712405-50.jpeg
#   inflating: CellData/OCT/train/DME/DME-7585537-6.jpeg
#   inflating: CellData/OCT/train/DME/DME-8259017-5.jpeg
#   inflating: CellData/OCT/train/DME/DME-4376118-14.jpeg
#   inflating: CellData/OCT/train/DME/DME-3542808-30.jpeg
#   inflating: CellData/OCT/train/DME/DME-778975-110.jpeg
#   inflating: CellData/OCT/train/DME/DME-5656004-43.jpeg
#   inflating: CellData/OCT/train/DME/DME-8426419-17.jpeg
#   inflating: CellData/OCT/train/DME/DME-7027665-2.jpeg
#   inflating: CellData/OCT/train/DME/DME-8019418-39.jpeg
#   inflating: CellData/OCT/train/DME/DME-7846574-27.jpeg
#   inflating: CellData/OCT/train/DME/DME-4030787-88.jpeg
#   inflating: CellData/OCT/train/DME/DME-7767265-18.jpeg
#   inflating: CellData/OCT/train/DME/DME-9126005-28.jpeg
#   inflating: CellData/OCT/train/DME/DME-5313093-54.jpeg
#   inflating: CellData/OCT/train/DME/DME-1896542-33.jpeg
#   inflating: CellData/OCT/train/DME/DME-8525575-124.jpeg
#   inflating: CellData/OCT/train/DME/DME-633268-53.jpeg
#   inflating: CellData/OCT/train/DME/DME-4967228-37.jpeg
#   inflating: CellData/OCT/train/DME/DME-4376118-9.jpeg
#   inflating: CellData/OCT/train/DME/DME-4578604-5.jpeg
#   inflating: CellData/OCT/train/DME/DME-3757443-49.jpeg
#   inflating: CellData/OCT/train/DME/DME-1591159-29.jpeg
#   inflating: CellData/OCT/train/DME/DME-3157783-10.jpeg
#   inflating: CellData/OCT/train/DME/DME-4242335-155.jpeg
#   inflating: CellData/OCT/train/DME/DME-465734-5.jpeg
#   inflating: CellData/OCT/train/DME/DME-9361825-26.jpeg
#   inflating: CellData/OCT/train/DME/DME-3441556-107.jpeg
#   inflating: CellData/OCT/train/DME/DME-4242335-45.jpeg
#   inflating: CellData/OCT/train/DME/DME-563695-5.jpeg
#   inflating: CellData/OCT/train/DME/DME-4921138-18.jpeg
#   inflating: CellData/OCT/train/DME/DME-5497895-37.jpeg
#   inflating: CellData/OCT/train/DME/DME-3509367-4.jpeg
#   inflating: CellData/OCT/train/DME/DME-8766603-12.jpeg
#   inflating: CellData/OCT/train/DME/DME-5223925-62.jpeg
#   inflating: CellData/OCT/train/DME/DME-4242335-7.jpeg
#   inflating: CellData/OCT/train/DME/DME-4445075-79.jpeg
#   inflating: CellData/OCT/train/DME/DME-7680244-15.jpeg
#   inflating: CellData/OCT/train/DME/DME-3441556-84.jpeg
#   inflating: CellData/OCT/train/DME/DME-4732091-61.jpeg
#   inflating: CellData/OCT/train/DME/DME-4630435-74.jpeg
#   inflating: CellData/OCT/train/DME/DME-403817-5.jpeg
#   inflating: CellData/OCT/train/DME/DME-8706454-5.jpeg
#   inflating: CellData/OCT/train/DME/DME-3414068-12.jpeg
#   inflating: CellData/OCT/train/DME/DME-4445075-6.jpeg
#   inflating: CellData/OCT/train/DME/DME-3276918-2.jpeg
#   inflating: CellData/OCT/train/DME/DME-5497895-26.jpeg
#   inflating: CellData/OCT/train/DME/DME-4242335-87.jpeg
#   inflating: CellData/OCT/train/DME/DME-6798210-31.jpeg
#   inflating: CellData/OCT/train/DME/DME-30521-58.jpeg
#   inflating: CellData/OCT/train/DME/DME-9915316-90.jpeg
#   inflating: CellData/OCT/train/DME/DME-4240465-6.jpeg
#   inflating: CellData/OCT/train/DME/DME-5313093-67.jpeg
#   inflating: CellData/OCT/train/DME/DME-8602716-83.jpeg
#   inflating: CellData/OCT/train/DME/DME-5225805-49.jpeg
#   inflating: CellData/OCT/train/DME/DME-3531101-26.jpeg
#   inflating: CellData/OCT/train/DME/DME-4244491-16.jpeg
#   inflating: CellData/OCT/train/DME/DME-5313093-2.jpeg
#   inflating: CellData/OCT/train/DME/DME-9126005-22.jpeg
#   inflating: CellData/OCT/train/DME/DME-4242335-84.jpeg
#   inflating: CellData/OCT/train/DME/DME-3346049-1.jpeg
#   inflating: CellData/OCT/train/DME/DME-1858286-1.jpeg
#   inflating: CellData/OCT/train/DME/DME-306172-31.jpeg
#   inflating: CellData/OCT/train/DME/DME-1966898-9.jpeg
#   inflating: CellData/OCT/train/DME/DME-1605248-8.jpeg
#   inflating: CellData/OCT/train/DME/DME-3304080-10.jpeg
#   inflating: CellData/OCT/train/DME/DME-5313093-5.jpeg
#   inflating: CellData/OCT/train/DME/DME-5549735-13.jpeg
#   inflating: CellData/OCT/train/DME/DME-7928636-8.jpeg
#   inflating: CellData/OCT/train/DME/DME-9721607-32.jpeg
#   inflating: CellData/OCT/train/DME/DME-6914545-2.jpeg
#   inflating: CellData/OCT/train/DME/DME-9590982-1.jpeg
#   inflating: CellData/OCT/train/DME/DME-5530115-3.jpeg
#   inflating: CellData/OCT/train/DME/DME-306172-69.jpeg
#   inflating: CellData/OCT/train/DME/DME-4630435-36.jpeg
#   inflating: CellData/OCT/train/DME/DME-30521-116.jpeg
#   inflating: CellData/OCT/train/DME/DME-1649492-47.jpeg
#   inflating: CellData/OCT/train/DME/DME-4759696-5.jpeg
#   inflating: CellData/OCT/train/DME/DME-682285-9.jpeg
#   inflating: CellData/OCT/train/DME/DME-4244491-1.jpeg
#   inflating: CellData/OCT/train/DME/DME-8080050-7.jpeg
#   inflating: CellData/OCT/train/DME/DME-3447259-3.jpeg
#   inflating: CellData/OCT/train/DME/DME-778975-127.jpeg
#   inflating: CellData/OCT/train/DME/DME-773094-4.jpeg
#   inflating: CellData/OCT/train/DME/DME-30521-126.jpeg
#   inflating: CellData/OCT/train/DME/DME-30521-74.jpeg
#   inflating: CellData/OCT/train/DME/DME-5437778-1.jpeg
#   inflating: CellData/OCT/train/DME/DME-917949-1.jpeg
#   inflating: CellData/OCT/train/DME/DME-119840-1.jpeg
#   inflating: CellData/OCT/train/DME/DME-4967228-38.jpeg
#   inflating: CellData/OCT/train/DME/DME-6878052-3.jpeg
#   inflating: CellData/OCT/train/DME/DME-4242335-144.jpeg
#   inflating: CellData/OCT/train/DME/DME-8479027-2.jpeg
#   inflating: CellData/OCT/train/DME/DME-7707202-12.jpeg
#   inflating: CellData/OCT/train/DME/DME-4030787-40.jpeg
#   inflating: CellData/OCT/train/DME/DME-778975-42.jpeg
#   inflating: CellData/OCT/train/DME/DME-6798210-57.jpeg
#   inflating: CellData/OCT/train/DME/DME-8021831-17.jpeg
#   inflating: CellData/OCT/train/DME/DME-4973751-18.jpeg
#   inflating: CellData/OCT/train/DME/DME-5851527-6.jpeg
#   inflating: CellData/OCT/train/DME/DME-3483651-18.jpeg
#   inflating: CellData/OCT/train/DME/DME-3757443-61.jpeg
#   inflating: CellData/OCT/train/DME/DME-8525575-134.jpeg
#   inflating: CellData/OCT/train/DME/DME-4630435-35.jpeg
#   inflating: CellData/OCT/train/DME/DME-4989358-40.jpeg
#   inflating: CellData/OCT/train/DME/DME-8869683-56.jpeg
#   inflating: CellData/OCT/train/DME/DME-403817-2.jpeg
#   inflating: CellData/OCT/train/DME/DME-3276918-19.jpeg
#   inflating: CellData/OCT/train/DME/DME-5572449-17.jpeg
#   inflating: CellData/OCT/train/DME/DME-3464701-1.jpeg
#   inflating: CellData/OCT/train/DME/DME-9915316-65.jpeg
#   inflating: CellData/OCT/train/DME/DME-8635355-3.jpeg
#   inflating: CellData/OCT/train/DME/DME-1750744-6.jpeg
#   inflating: CellData/OCT/train/DME/DME-3157783-115.jpeg
#   inflating: CellData/OCT/train/DME/DME-3157783-46.jpeg
#   inflating: CellData/OCT/train/DME/DME-5225805-41.jpeg
#   inflating: CellData/OCT/train/DME/DME-4445075-49.jpeg
#   inflating: CellData/OCT/train/DME/DME-5014129-14.jpeg
#   inflating: CellData/OCT/train/DME/DME-408201-12.jpeg
#   inflating: CellData/OCT/train/DME/DME-9836152-31.jpeg
#   inflating: CellData/OCT/train/DME/DME-5289136-3.jpeg
#   inflating: CellData/OCT/train/DME/DME-5071032-9.jpeg
#   inflating: CellData/OCT/train/DME/DME-4244491-13.jpeg
#   inflating: CellData/OCT/train/DME/DME-8788274-1.jpeg
#   inflating: CellData/OCT/train/DME/DME-4897748-66.jpeg
#   inflating: CellData/OCT/train/DME/DME-7707202-26.jpeg
#   inflating: CellData/OCT/train/DME/DME-7763916-82.jpeg
#   inflating: CellData/OCT/train/DME/DME-3157783-55.jpeg
#   inflating: CellData/OCT/train/DME/DME-5203422-2.jpeg
#   inflating: CellData/OCT/train/DME/DME-4242335-159.jpeg
#   inflating: CellData/OCT/train/DME/DME-8525575-90.jpeg
#   inflating: CellData/OCT/train/DME/DME-633268-71.jpeg
#   inflating: CellData/OCT/train/DME/DME-8371885-12.jpeg
#   inflating: CellData/OCT/train/DME/DME-8770531-16.jpeg
#   inflating: CellData/OCT/train/DME/DME-8861620-1.jpeg
#   inflating: CellData/OCT/train/DME/DME-8525575-188.jpeg
#   inflating: CellData/OCT/train/DME/DME-1896542-12.jpeg
#   inflating: CellData/OCT/train/DME/DME-4792882-4.jpeg
#   inflating: CellData/OCT/train/DME/DME-3340887-2.jpeg
#   inflating: CellData/OCT/train/DME/DME-1695472-13.jpeg
#   inflating: CellData/OCT/train/DME/DME-9997680-3.jpeg
#   inflating: CellData/OCT/train/DME/DME-8477096-4.jpeg
#   inflating: CellData/OCT/train/DME/DME-5072525-2.jpeg
#   inflating: CellData/OCT/train/DME/DME-5313093-1.jpeg
#   inflating: CellData/OCT/train/DME/DME-4732091-5.jpeg
#   inflating: CellData/OCT/train/DME/DME-7939555-12.jpeg
#   inflating: CellData/OCT/train/DME/DME-306172-74.jpeg
#   inflating: CellData/OCT/train/DME/DME-1808783-13.jpeg
#   inflating: CellData/OCT/train/DME/DME-9126005-9.jpeg
#   inflating: CellData/OCT/train/DME/DME-4119721-44.jpeg
#   inflating: CellData/OCT/train/DME/DME-8889771-66.jpeg
#   inflating: CellData/OCT/train/DME/DME-7917652-8.jpeg
#   inflating: CellData/OCT/train/DME/DME-1591159-53.jpeg
# ...
#   inflating: CellData/OCT/test/CNV/CNV-5898110-1.jpeg
#   inflating: CellData/OCT/test/CNV/CNV-8258303-1.jpeg
#   inflating: CellData/OCT/test/CNV/CNV-9499888-11.jpeg
#   inflating: CellData/OCT/test/CNV/CNV-500700-1.jpeg
#   inflating: CellData/OCT/test/CNV/CNV-6403097-1.jpeg
#   inflating: CellData/OCT/test/CNV/CNV-4072161-1.jpeg
#   inflating: CellData/OCT/test/CNV/CNV-8713483-1.jpeg
#   inflating: CellData/OCT/test/CNV/CNV-9385891-1.jpeg
#   inflating: CellData/OCT/test/CNV/CNV-9499888-3.jpeg
#   inflating: CellData/OCT/test/CNV/CNV-2419660-1.jpeg
#   inflating: CellData/OCT/test/CNV/CNV-346788-2.jpeg
#   inflating: CellData/OCT/test/CNV/CNV-5737653-1.jpeg
#   inflating: CellData/OCT/test/CNV/CNV-2347105-1.jpeg
#   inflating: CellData/OCT/test/CNV/CNV-781743-1.jpeg
#   inflating: CellData/OCT/test/CNV/CNV-7405074-2.jpeg
#   inflating: CellData/OCT/test/CNV/CNV-818474-3.jpeg
#   inflating: CellData/OCT/test/CNV/CNV-818474-1.jpeg
#   inflating: CellData/OCT/test/CNV/CNV-1256555-4.jpeg
#   inflating: CellData/OCT/test/CNV/CNV-3617684-1.jpeg
#   inflating: CellData/OCT/test/CNV/CNV-9617911-2.jpeg
#   inflating: CellData/OCT/test/CNV/CNV-1183551-1.jpeg
#   inflating: CellData/OCT/test/CNV/CNV-2224582-1.jpeg
#   inflating: CellData/OCT/test/CNV/CNV-311613-1.jpeg
#   inflating: CellData/OCT/test/CNV/CNV-734155-1.jpeg
#   inflating: CellData/OCT/test/CNV/CNV-667621-1.jpeg
#   inflating: CellData/OCT/test/CNV/CNV-9782524-2.jpeg
#   inflating: CellData/OCT/test/CNV/CNV-1246827-1.jpeg
#   inflating: CellData/OCT/test/CNV/CNV-6853602-1.jpeg
#   inflating: CellData/OCT/test/CNV/CNV-7954652-1.jpeg
#   inflating: CellData/OCT/test/CNV/CNV-1284842-1.jpeg
#    creating: CellData/OCT/test/DME/
#   inflating: CellData/OCT/test/DME/DME-3207323-2.jpeg
#   inflating: CellData/OCT/test/DME/DME-32711-2.jpeg
#   inflating: CellData/OCT/test/DME/DME-3013082-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-1136125-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-6486712-2.jpeg
#   inflating: CellData/OCT/test/DME/DME-1074708-2.jpeg
#   inflating: CellData/OCT/test/DME/DME-3748177-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-7060258-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-486550-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-6202565-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-5546730-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-247204-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-3748177-2.jpeg
#   inflating: CellData/OCT/test/DME/DME-698993-6.jpeg
#   inflating: CellData/OCT/test/DME/DME-943690-16.jpeg
#   inflating: CellData/OCT/test/DME/DME-6953909-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-7345914-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-3665559-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-957578-2.jpeg
#   inflating: CellData/OCT/test/DME/DME-752545-2.jpeg
#   inflating: CellData/OCT/test/DME/DME-859014-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-5398756-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-3808130-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-943690-9.jpeg
#   inflating: CellData/OCT/test/DME/DME-7345914-2.jpeg
#   inflating: CellData/OCT/test/DME/DME-1682252-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-3638623-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-5501893-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-289085-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-2250041-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-3147908-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-7222853-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-2889164-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-943690-17.jpeg
#   inflating: CellData/OCT/test/DME/DME-6486712-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-2144724-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-6225626-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-85452-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-1029576-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-7315099-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-1781938-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-3558560-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-4480087-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-5466077-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-740597-2.jpeg
#   inflating: CellData/OCT/test/DME/DME-925077-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-901538-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-145590-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-294654-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-3248431-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-1930055-2.jpeg
#   inflating: CellData/OCT/test/DME/DME-145590-2.jpeg
#   inflating: CellData/OCT/test/DME/DME-75834-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-493576-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-585163-2.jpeg
#   inflating: CellData/OCT/test/DME/DME-357462-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-32711-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-943690-2.jpeg
#   inflating: CellData/OCT/test/DME/DME-943690-4.jpeg
#   inflating: CellData/OCT/test/DME/DME-657432-2.jpeg
#   inflating: CellData/OCT/test/DME/DME-4594014-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-145590-4.jpeg
#   inflating: CellData/OCT/test/DME/DME-4892635-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-943690-15.jpeg
#   inflating: CellData/OCT/test/DME/DME-698993-5.jpeg
#   inflating: CellData/OCT/test/DME/DME-690653-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-4528883-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-4624778-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-7423072-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-1543479-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-2061433-3.jpeg
#   inflating: CellData/OCT/test/DME/DME-3087843-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-247204-2.jpeg
#   inflating: CellData/OCT/test/DME/DME-3433573-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-2250041-2.jpeg
#   inflating: CellData/OCT/test/DME/DME-6767872-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-3198088-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-6244502-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-436344-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-957578-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-904971-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-6539987-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-894860-2.jpeg
#   inflating: CellData/OCT/test/DME/DME-3259356-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-287279-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-6486712-3.jpeg
#   inflating: CellData/OCT/test/DME/DME-657432-3.jpeg
#   inflating: CellData/OCT/test/DME/DME-835216-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-3207323-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-4480087-2.jpeg
#   inflating: CellData/OCT/test/DME/DME-296730-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-4644266-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-4957841-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-3273592-2.jpeg
#   inflating: CellData/OCT/test/DME/DME-505076-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-145590-3.jpeg
#   inflating: CellData/OCT/test/DME/DME-6973079-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-585163-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-3444601-2.jpeg
#   inflating: CellData/OCT/test/DME/DME-4588512-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-880307-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-59355-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-626704-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-812890-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-205260-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-3013082-2.jpeg
#   inflating: CellData/OCT/test/DME/DME-3444601-3.jpeg
#   inflating: CellData/OCT/test/DME/DME-85452-6.jpeg
#   inflating: CellData/OCT/test/DME/DME-4016839-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-3105687-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-585163-4.jpeg
#   inflating: CellData/OCT/test/DME/DME-2061433-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-698993-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-585163-3.jpeg
#   inflating: CellData/OCT/test/DME/DME-3446806-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-1692430-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-81377-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-865337-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-2061433-2.jpeg
#   inflating: CellData/OCT/test/DME/DME-5546730-3.jpeg
#   inflating: CellData/OCT/test/DME/DME-943690-10.jpeg
#   inflating: CellData/OCT/test/DME/DME-5466312-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-1358659-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-3826515-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-4920070-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-85452-3.jpeg
#   inflating: CellData/OCT/test/DME/DME-657432-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-855282-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-764149-3.jpeg
#   inflating: CellData/OCT/test/DME/DME-4805212-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-1868024-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-3273592-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-4485446-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-943690-11.jpeg
#   inflating: CellData/OCT/test/DME/DME-85452-2.jpeg
#   inflating: CellData/OCT/test/DME/DME-3287865-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-835216-2.jpeg
#   inflating: CellData/OCT/test/DME/DME-999838-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-943690-3.jpeg
#   inflating: CellData/OCT/test/DME/DME-4609916-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-261328-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-245643-3.jpeg
#   inflating: CellData/OCT/test/DME/DME-1569-2.jpeg
#   inflating: CellData/OCT/test/DME/DME-1208299-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-6547774-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-1029576-3.jpeg
#   inflating: CellData/OCT/test/DME/DME-1029576-4.jpeg
#   inflating: CellData/OCT/test/DME/DME-943690-8.jpeg
#   inflating: CellData/OCT/test/DME/DME-1348407-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-943690-12.jpeg
#   inflating: CellData/OCT/test/DME/DME-1094647-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-484530-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-489256-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-7003978-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-1208299-2.jpeg
#   inflating: CellData/OCT/test/DME/DME-752545-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-261328-2.jpeg
#   inflating: CellData/OCT/test/DME/DME-1055504-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-2140236-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-943690-6.jpeg
#   inflating: CellData/OCT/test/DME/DME-1453560-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-6477061-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-1029576-2.jpeg
#   inflating: CellData/OCT/test/DME/DME-85452-4.jpeg
#   inflating: CellData/OCT/test/DME/DME-4680138-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-7066515-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-185005-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-6202565-2.jpeg
#   inflating: CellData/OCT/test/DME/DME-3783089-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-943690-5.jpeg
#   inflating: CellData/OCT/test/DME/DME-1029576-5.jpeg
#   inflating: CellData/OCT/test/DME/DME-2226375-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-740597-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-2525419-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-7843895-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-6721786-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-6796856-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-764149-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-1941324-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-783607-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-4495353-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-5242109-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-5304546-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-1043402-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-953126-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-1682252-2.jpeg
#   inflating: CellData/OCT/test/DME/DME-1569-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-3300738-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-698993-3.jpeg
#   inflating: CellData/OCT/test/DME/DME-7843895-2.jpeg
#   inflating: CellData/OCT/test/DME/DME-763885-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-1074708-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-3923620-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-3586247-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-245643-2.jpeg
#   inflating: CellData/OCT/test/DME/DME-3367544-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-2128117-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-5546730-4.jpeg
#   inflating: CellData/OCT/test/DME/DME-3248431-2.jpeg
#   inflating: CellData/OCT/test/DME/DME-493469-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-3924406-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-1839247-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-596173-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-2328103-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-1805165-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-4609916-3.jpeg
#   inflating: CellData/OCT/test/DME/DME-925077-2.jpeg
#   inflating: CellData/OCT/test/DME/DME-3894007-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-894860-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-5284675-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-5195971-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-2478669-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-943690-7.jpeg
#   inflating: CellData/OCT/test/DME/DME-2587510-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-180600-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-698993-2.jpeg
#   inflating: CellData/OCT/test/DME/DME-2342892-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-4495353-2.jpeg
#   inflating: CellData/OCT/test/DME/DME-943690-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-3259356-2.jpeg
#   inflating: CellData/OCT/test/DME/DME-845804-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-734479-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-85452-5.jpeg
#   inflating: CellData/OCT/test/DME/DME-5195971-2.jpeg
#   inflating: CellData/OCT/test/DME/DME-591617-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-328548-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-48861-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-2895526-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-764149-2.jpeg
#   inflating: CellData/OCT/test/DME/DME-698993-4.jpeg
#   inflating: CellData/OCT/test/DME/DME-1930055-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-3444601-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-902126-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-6397724-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-619944-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-1097163-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-5546730-2.jpeg
#   inflating: CellData/OCT/test/DME/DME-943690-13.jpeg
#   inflating: CellData/OCT/test/DME/DME-1682252-3.jpeg
#   inflating: CellData/OCT/test/DME/DME-4609916-2.jpeg
#   inflating: CellData/OCT/test/DME/DME-245643-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-943690-14.jpeg
#   inflating: CellData/OCT/test/DME/DME-483195-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-7843895-3.jpeg
#   inflating: CellData/OCT/test/DME/DME-643307-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-3694670-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-437920-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-925077-3.jpeg
#   inflating: CellData/OCT/test/DME/DME-7224935-1.jpeg
#   inflating: CellData/OCT/test/DME/DME-1403231-1.jpeg
#   inflating: CellData/code/net/train.pyc
#  extracting: CellData/code/net/__init__.py
#   inflating: CellData/code/net/utils.py
#   inflating: CellData/code/net/train.py
#   inflating: CellData/code/net/__init__.pyc
#   inflating: CellData/code/net/utils.pyc
#   inflating: CellData/code/occlusion.py
#   inflating: CellData/code/retrain.py
#   inflating: CellData/code/README.md

# %% [markdown]
# ## Preparing the Dataset

# %% [markdown]
# I defined the transformations, a class for loading the images which is used later, and built the train and test set for the optical coherence tomography (OCT) images. I also split off a random subset of the train data to train my EncoderForClassifier which is defined later.

# %%
GRAY_MEAN = [0.5]
GRAY_STD = [0.5]

train_transform = transforms.Compose(
    [
        transforms.Lambda(lambda x: x.convert("L")),
        transforms.Resize((128,128)),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize(mean=GRAY_MEAN, std=GRAY_STD)
    ]
)

val_transform = transforms.Compose(
    [
        transforms.Lambda(lambda x: x.convert("L")),
        transforms.Resize((128,128)),
        transforms.ToTensor(),
        transforms.Normalize(mean=GRAY_MEAN, std=GRAY_STD)
    ]
)

"""
Class for Loading Images
"""
class ImageLoaderDataset(nn.Module):
    def __init__(self, path_to_folder, transform):
        """
        Initializes instance of the ImageLoaderDataset Class

        Parameters:
        self (ImageLoaderDataset): instance of the class
        path_to_folder (str): the path to the data
        transform (transforms): the transformation to the data
        """

        self.path_to_folder = path_to_folder
        self.training_files = os.listdir(path_to_folder)
        self.transform = transform

    def __len__(self):
        """
        Returns the length of the data files

        Parameter:
        self (ImageLoaderDataset): instance of the class

        Returns:
        int: the length of training files
        """
        return len(self.training_files)

    def __getitem__(self, idx):
        """
        Gets the image at an index in the training files

        Parameters:
        self (ImageLoaderDataset): instance of the class
        idx (int): the index of the image you are returning

        Returns:
        Image: the image at that index
        """
        sample = self.training_files[idx]
        path_to_sample = os.path.join(self.path_to_folder, sample)

        image = Image.open(path_to_sample).convert("L")
        image = self.transform(image)

        return image

## Using Image Folder to Build the Train and Test Dataset ##
train_set = ImageFolder(PATH_TRAIN, transform=train_transform)
test_set = ImageFolder(PATH_TEST, transform=train_transform)

## Assigning Each Class an index ##
data_classes = {idx: val for (idx, val) in enumerate(train_set.classes)}

## Choosing a Random Subset for Pretraining ##
random_indices = random.sample(range(len(train_set)), int(len(train_set) * train_set_pct))
train_set = Subset(train_set, random_indices)

print(f"Training with {len(train_set)} samples")
# Out:
# Training with 108309 samples

# %% [markdown]
# ## Defining ResidualBlocks & The Encoder

# %% [markdown]
# Next, I defined a class for ResidualBlocks and the other key encoding classes: the EncoderBlocks, the Encoder, and the EncoderForClassifier, which I will later train on the subset of the data.

# %%
"""
ResidualBlock: a class that represents a block of residual connections
"""
class ResidualBlock(nn.Module):

    def __init__(self,
                 in_channels,
                 out_channels,
                 dropout_p=0.0):
        """
        Initializes the ResidualBlock class.

        Parameters:
        self (Residual Block): instance of the class
        in_channels (int): number of input channels
        out_channels (int): number of output channels
        dropout_p (float): dropout probability percent if you are randomly turning off some % of nodes, set to 0
        """

        super().__init__()

        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=1, padding="same")
        self.norm1 = nn.BatchNorm2d(out_channels)

        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, padding="same")
        self.norm2 = nn.BatchNorm2d(out_channels)

        self.identity_conv = nn.Identity()
        if in_channels != out_channels:
            self.identity_conv = nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=1)

    def forward(self, x):
        """
        Forward function for ResidualBlock. Applies a residual connection by applying a convolution
        that goes from the input channels to the output channels with stride=1, applies a BatchNorm2d and
        then the activation function. Applies a second convolution from output channels to output channels and
        a BatchNorm2d and then activation again. Finally, it has the residual effect by adding the identity on the residual.

        Parameters:
        self (ResidualBlock): instance of the class
        x: the input to the block

        Returns:
        x: the output after adding the residual
        """
        residual = x

        x = self.conv1(x)
        x = self.norm1(x)
        x = F.relu(x)

        x = self.conv2(x)
        x = self.norm2(x)
        x = F.relu(x)

        x = x + self.identity_conv(residual)

        return x

"""
EncoderBlock: a class that defines the structure and ResidualBlocks that make up the Encoder
of my VAE.
"""
class EncoderBlock(nn.Module):
    def __init__(self,
                 in_channels,
                 out_channels,
                 residual_blocks_per_group=1,
                 downsample=True,
                 dropout_p=0.0):
      """
      Initializes an instance of the EncoderBlock class.

      Parameters:
      self (EncoderBlock): instance of the class
      in_channels (int): number of input channels
      out_channels (int): number of output channels
      residual_blocks_per_group (int): number of ResidualBlocks per group, set to 1
      downsample (bool): True if downsampling, else False
      dropout_p(float): % of nodes randomly turned off, set to 0.0
      """

      super().__init__()

      self.encoder_block = nn.ModuleList([])
      for i in range(residual_blocks_per_group):
          in_c = in_channels if i == 0 else out_channels
          self.encoder_block.append(
              ResidualBlock(in_c, out_channels, dropout_p)
          )

      if downsample:
          self.encoder_block.append(
              nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=2, padding=1)
          )

    def forward(self, x):
        """
        Forward function for the EncoderBlock that specifies how input flows through the network.

        Parameters:
        self (EncoderBlock): instance of the class
        x: the input passed to the layer
        """

        for block in self.encoder_block:
            x = block(x)

        return x
"""
Encoder: encoder class for the VAE, which has a sequence of EncoderBlocks which go through a channel pattern
and which downsample.
"""
class Encoder(nn.Module):
    """
    Initializes the Encoder class

    Parameters:
    self (Encoder): instance of the class
    in_channels (int): number of input channels
    channel_pattern (array): the pattern of number of channels for the encoder.
                            If None, default is [32,64,128,256]
    residual_blocks_per_group (int): the number of residual blocks per group, set to 1
    dropout_p (float): percent of nodes randomly turned off, set to 0.0
    """
    def __init__(self,
                  in_channels,
                  channel_pattern=None,
                  residual_blocks_per_group=1,
                  dropout_p=0.0):

        super().__init__()

        self.channel_pattern = channel_pattern
        if channel_pattern is None:
            self.channel_pattern = [32,64,128,256]


        self.blocks1 = EncoderBlock(in_channels,
                                    self.channel_pattern[0],
                                    residual_blocks_per_group=residual_blocks_per_group,
                                    downsample=True,
                                    dropout_p=dropout_p)

        self.blocks2 = EncoderBlock(self.channel_pattern[0],
                                    self.channel_pattern[1],
                                    residual_blocks_per_group=residual_blocks_per_group,
                                    downsample=True,
                                    dropout_p=dropout_p)

        self.blocks3 = EncoderBlock(self.channel_pattern[1],
                                    self.channel_pattern[2],
                                    residual_blocks_per_group=residual_blocks_per_group,
                                    downsample=True,
                                    dropout_p=dropout_p)

        self.blocks4 = EncoderBlock(self.channel_pattern[2],
                                    self.channel_pattern[3],
                                    residual_blocks_per_group=residual_blocks_per_group,
                                    downsample=True,
                                    dropout_p=dropout_p)

    def forward(self, x):
        """
        The forward function for the Encoder that specifies how input flows through the
        network. It goes through all 4 encoder blocks.
        """

        x = self.blocks1(x)
        x = self.blocks2(x)
        x = self.blocks3(x)
        x = self.blocks4(x)

        return x

"""
EncoderForClassifier: This is the encoder which learns the classification, being
trained later on just a percent of the data. I will use this to load pretrained weights
to the encoder of the VAE later.
"""
class EncoderForClassifier(nn.Module):
    """
    Initializes the EncoderForClassifier.

    Parameters:
    self (Encoder): instance of the class
    num_classes (int): number of classes, set to four since the OCT dataset has four
    in_channels (int): number of input channels
    channel_pattern (array): the pattern of number of channels for the encoder.
                            If None, default is [32,64,128,256]
    residual_blocks_per_group (int): the number of residual blocks per group, set to 1
    dropout_p (float): percent of nodes randomly turned off, set to 0.0
    """
    def __init__(self,
                  num_classes=4,
                  in_channels=3,
                  channel_pattern=None,
                  residual_blocks_per_group=1,
                  dropout_p=0.0):
        super().__init__()

        self.encoder = Encoder(in_channels,
                                channel_pattern=None,
                                residual_blocks_per_group=1,
                                dropout_p=0.0)

        self.head = nn.Linear(self.encoder.channel_pattern[-1] * 8 * 8, num_classes)
    """
    Forward function for the EncoderForClassifier

    Parameters:
    self (EncoderForClassifier): instance of the class
    x: input passed to EncoderForClassifier
    """
    def forward(self, x):
        x = self.encoder(x)
        x = x.flatten(1)
        x = self.head(x)
        return x

# %% [markdown]
# ## Train Classifier on Subset

# %% [markdown]
# Here, I wrote my training script and trained the EncoderForClassifier on a subset of the data. I also saved the state dict of the encoder with the file name "vae18_encoder" + str(train_set_pct*100) +"_c.pt," so for example, if I trained the model on 10% it would be saved to vae18_encoder10.0_c.pt. I saved all these state dicts through my experimentation.

# %%
"""
Training function for the EncoderForClassifier

Parameters:
model: the model being trained
device: the device being used
epochs (int): number of epochs
optimizer: the optimizer
loss_fn: the loss function
trainloader: the data loader for the training data
valloader: the data loader for the test data

Returns:
log_training: the training log that specifies the epoch, training loss, training
accuracy, validation loss, and validation accuracy.
model: the model
"""
def train(model, device, epochs, optimizer, loss_fn, trainloader, valloader):
    log_training = {"epoch": [],
                    "training_loss": [],
                    "training_acc": [],
                    "validation_loss": [],
                    "validation_acc": []}

    model = model.to(device)

    for epoch in range(1, epochs + 1):
        print(f"Starting Epoch {epoch}")
        training_losses, training_accuracies = [], []
        validation_losses, validation_accuracies = [], []

        model.train()
        for image, label in tqdm(trainloader):
            image, label = image.to(device), label.to(device)
            optimizer.zero_grad()
            out = model.forward(image)

            ## Calculate Loss ##
            loss = loss_fn(out, label)
            training_losses.append(loss.item())

            ## Calculate Accuracy ##
            predictions = torch.argmax(out, axis=1)
            accuracy = (predictions == label).sum() / len(predictions)
            training_accuracies.append(accuracy.item())

            loss.backward()
            optimizer.step()

        model.eval() ## BatchNorm is Off ##
        for image, label in tqdm(valloader):
            image, label = image.to(device), label.to(device)
            with torch.no_grad():
                out = model.forward(image)

                ## Calculate Loss ##
                loss = loss_fn(out, label)
                validation_losses.append(loss.item())

                ## Calculate Accuracy ##
                predictions = torch.argmax(out, axis=1)
                accuracy = (predictions == label).sum() / len(predictions)
                validation_accuracies.append(accuracy.item())

        training_loss_mean, training_acc_mean = np.mean(training_losses), np.mean(training_accuracies)
        valid_loss_mean, valid_acc_mean = np.mean(validation_losses), np.mean(validation_accuracies)

        log_training["epoch"].append(epoch)
        log_training["training_loss"].append(training_loss_mean)
        log_training["training_acc"].append(training_acc_mean)
        log_training["validation_loss"].append(valid_loss_mean)
        log_training["validation_acc"].append(valid_acc_mean)

        print("Training Loss:", training_loss_mean)
        print("Training Acc:", training_acc_mean)
        print("Validation Loss:", valid_loss_mean)
        print("Validation Acc:", valid_acc_mean)

    return log_training, model

model = EncoderForClassifier(in_channels=1)
device = "cuda" if torch.cuda.is_available() else "cpu"
epochs = 5
optimizer = torch.optim.AdamW(model.parameters(), lr=0.0001, weight_decay=0.01)
loss_fn = nn.CrossEntropyLoss()
trainloader = DataLoader(train_set, batch_size=64, shuffle=True, num_workers=16)
testloader = DataLoader(test_set, batch_size=64, shuffle=False, num_workers=16)

log_training, model = train(model=model,
                            device=device,
                            epochs=epochs,
                            optimizer=optimizer,
                            loss_fn=loss_fn,
                            trainloader=trainloader,
                            valloader=testloader)

## Saving the State Dict ##
torch.save(model.encoder.state_dict(), "vae18_encoder" + str(train_set_pct*100) +"_c.pt")
# Out:
# Starting Epoch 1
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 12, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
#   0%|          | 0/1693 [00:00<?, ?it/s]
#   0%|          | 0/16 [00:00<?, ?it/s]
# Training Loss: 0.3283394817779984
# Training Acc: 0.8874769710043937
# Validation Loss: 0.3839659122750163
# Validation Acc: 0.8681640625
# Starting Epoch 2
#   0%|          | 0/1693 [00:00<?, ?it/s]
#   0%|          | 0/16 [00:00<?, ?it/s]
# Training Loss: 0.1792134754095673
# Training Acc: 0.9405917749556999
# Validation Loss: 0.17551575630204752
# Validation Acc: 0.9441406242549419
# Starting Epoch 3
#   0%|          | 0/1693 [00:00<?, ?it/s]
#   0%|          | 0/16 [00:00<?, ?it/s]
# Training Loss: 0.14716229114870719
# Training Acc: 0.9518140171029057
# Validation Loss: 0.2518170809635194
# Validation Acc: 0.9228515625
# Starting Epoch 4
#   0%|          | 0/1693 [00:00<?, ?it/s]
#   0%|          | 0/16 [00:00<?, ?it/s]
# Training Loss: 0.12504481181240493
# Training Acc: 0.9589754205023263
# Validation Loss: 0.28910541243385524
# Validation Acc: 0.8998046889901161
# Starting Epoch 5
#   0%|          | 0/1693 [00:00<?, ?it/s]
#   0%|          | 0/16 [00:00<?, ?it/s]
# Training Loss: 0.11378587242072845
# Training Acc: 0.9627048877731837
# Validation Loss: 0.11165191431064159
# Validation Acc: 0.96484375

# %% [markdown]
# ### Defining my VAE

# %% [markdown]
# I defined the main Variational Autoencoder model. Of course, I had to define relevant classes including the class for upsampling and the Decoder (along with the DecoderBlock) for this task.

# %%
"""
UpsampleBlock: Class for Upsampling for the VAE since Residual COnnections alone don't
change image resolution
"""
class UpsampleBlock(nn.Module):
    def __init__(self,
                  in_channels,
                  out_channels):
        """
        Initializes UpsampleBlock

        Parameters:
        self (UpsampleBlock): instance of the class
        in_channels (int): number of input channels
        out_channels (int): number of output channels
        """
        super().__init__()

        self.up = nn.Sequential(
            nn.Upsample(scale_factor=2),
            nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=1, padding="same")
        )

    def forward(self, x):
        """
        Forward function for UpsampleBlock that applies upsampling to the input

        Parameters:
        self (UpSampleBlock): instance of the class
        x: input passed into model
        """
        return self.up(x)

"""
DecoderBlock: a class that details the structure of residual blocks in the decoder.
"""
class DecoderBlock(nn.Module):
    def __init__(self,
                 in_channels,
                 out_channels,
                 residual_blocks_per_group=1,
                 upsample=True,
                 dropout_p=0.0):
        """
        Initializes the DecoderBlock.

        Parameters:
        self (DecoderBlock): instance of the class
        in_channels (int): number of input channels
        out_channels (int): number of output channels
        residual_blocks_per_group (int): number of ResidualBlocks per group, set to 1
        upsample (bool): True if upsampling, else False
        dropout_p(float): % of nodes randomly turned off, set to 0.0

        """

        super().__init__()

        self.encoder_block = nn.ModuleList([])
        for i in range(residual_blocks_per_group):
            in_c = in_channels if i == 0 else out_channels
            self.encoder_block.append(
                ResidualBlock(in_c, out_channels, dropout_p)
            )

        if upsample:
            self.encoder_block.append(
                UpsampleBlock(out_channels, out_channels)
            )

    def forward(self, x):
        """
        Forward function for the DecoderBlock that specifies how input
        flows through the network's layers.

        Parameters:
        self (DecoderBlock): instance of the class
        x: the input passed to the layer
        """
        for block in self.encoder_block:
            x = block(x)

        return x

"""
Decoder: decoder class for the VAE, which has a sequence of DecoderBlocks which go through a channel pattern
and which upsample.
"""
class Decoder(nn.Module):
    def __init__(self,
                 out_channels,
                 channel_pattern=None,
                 residual_blocks_per_group=1,
                 dropout_p=0.0):
        """
        Initializes the Encoder class

        Parameters:
        self (Decoder): instance of the class
        out_channels (int): number of output channels
        channel_pattern (array): the pattern of number of channels for the encoder.
                                  If None, default is [32,64,128,256]
        residual_blocks_per_group (int): the number of residual blocks per group, set to 1
        dropout_p (float): percent of nodes randomly turned off, set to 0.0
        """
        super().__init__()

        self.channel_pattern = channel_pattern
        if channel_pattern is None:
            self.channel_pattern = [32,64,128,256]
        self.channel_pattern = list(reversed(self.channel_pattern))

        self.blocks1 = DecoderBlock(self.channel_pattern[0],
                                    self.channel_pattern[1],
                                    residual_blocks_per_group=residual_blocks_per_group,
                                    upsample=True,
                                    dropout_p=dropout_p)

        self.blocks2 = DecoderBlock(self.channel_pattern[1],
                                    self.channel_pattern[2],
                                    residual_blocks_per_group=residual_blocks_per_group,
                                    upsample=True,
                                    dropout_p=dropout_p)

        self.blocks3 = DecoderBlock(self.channel_pattern[2],
                                    self.channel_pattern[3],
                                    residual_blocks_per_group=residual_blocks_per_group,
                                    upsample=True,
                                    dropout_p=dropout_p)

        self.blocks4 = DecoderBlock(self.channel_pattern[3],
                                    out_channels,
                                    residual_blocks_per_group=residual_blocks_per_group,
                                    upsample=True,
                                    dropout_p=dropout_p)

    def forward(self, x):
        """
        The forward function for the Decoder that specifies how input flows through the
        network. It goes through all 4 decoder blocks.
        """
        x = self.blocks1(x)
        x = self.blocks2(x)
        x = self.blocks3(x)
        x = self.blocks4(x)

        return x

"""
VAE: Variational Autoencoder
"""
class VAE(nn.Module):
    def __init__(self,
                 in_channels,
                 latent_channels=16,
                 channel_pattern=None,
                 residual_blocks_per_group=1,
                 dropout_p=0.0):
        """
        Initializes the VAE class

        Parameters:
        self (VAE): instance of the class
        in_channels (int): number of input channels
        latent_channels (int): number of latent channels
        channel_pattern (array): the pattern of number of channels for the encoder.
                                  If None, default is [32,64,128,256]
        residual_blocks_per_group (int): the number of residual blocks per group, set to 1
        dropout_p (float): percent of nodes randomly turned off, set to 0.0
        """
        super().__init__()

        self.channel_pattern = channel_pattern
        if channel_pattern is None:
            self.channel_pattern = [32,64,128,256]

        self.encoder = Encoder(in_channels=in_channels,
                               channel_pattern=self.channel_pattern,
                               residual_blocks_per_group=residual_blocks_per_group,
                               dropout_p=dropout_p)

        self.decoder = Decoder(out_channels=in_channels,
                               channel_pattern=self.channel_pattern,
                               residual_blocks_per_group=residual_blocks_per_group,
                               dropout_p=dropout_p)

        self.proj_to_latent = nn.Conv2d(self.channel_pattern[-1],
                                        latent_channels * 2,
                                        kernel_size=1,
                                        padding="same")

        self.latent_to_proj = nn.Conv2d(latent_channels,
                                        self.channel_pattern[-1],
                                        kernel_size=1,
                                        padding="same")

    def kl_loss(self, mean, logvar):
        """
        Loss function for kL divergence, finds the loss for each pixel
        and then averages it.

        Parameters:
        self (VAE): instance of class
        mean (float): the mean
        logvar (float): the log variance
        """
        var = torch.exp(logvar)

        kl_loss = -0.5 * torch.sum(
            1 + logvar - mean**2 - var,
            dim=[1,2,3]
        )

        kl_loss = kl_loss.mean()

        return kl_loss

    def encode(self, x):
        """
        Function that describes how the VAE encodes: following the channel pattern, projecting to 2*latent space
        and then finding the mu and logvar.
        Pretrained weights will be added for the no_grad() portion of it.

        Parameters:
        self (VAE): instance of class
        x: the input passed in to the encoder

        Returns:
        z: the probabilistic distribution
        mu: the mean
        logvar: the log variance
        """
        with torch.no_grad():
            x = self.encoder(x)

        x = self.proj_to_latent(x)

        mu, logvar = torch.chunk(x, chunks=2, dim=1)
        logvar = torch.clamp(logvar, min=-30, max=20)
        sigma = torch.exp(0.5 * logvar)
        noise = torch.randn_like(sigma, device=sigma.device, dtype=sigma.dtype)
        z = mu + sigma * noise

        return z, mu, logvar

    def decode(self, x):
        """
        Function that does the decoding. Goes from the latent/bottleneck space then the
        decoder blocks.

        Parameters:
        self (VAE): instance of class
        x: input
        """

        x = self.latent_to_proj(x)
        x = self.decoder(x)

        return x

    def forward(self, x):
        """
        The forward function for the VAE. Goes through the encoder and decoder.

        Parameters:
        self (VAE): instance of class
        x: input

        Returns:
        enc: the encoded features
        dec: the decoded image
        kl_loss: the kL loss
        """

        enc, mu, logvar = self.encode(x)
        dec = self.decode(enc)

        kl_loss = self.kl_loss(mu, logvar)

        return enc, dec, kl_loss

# %% [markdown]
# ### Training the VAE ###

# %% [markdown]
# Next, I trained my VAE.

# %%
def train(model,
          kl_weight,
          train_set,
          test_set,
          batch_size,
          training_iterations,
          evaluation_iterations):
    """
    Training Script for the VAE.

    Parameters:
    model: the model
    kl_weight: the weight for the kL divergence loss
    train_set: the train set
    test_set: the test set
    batch_size: the batch size
    training_iterations: the number of training iterations
    evaluation_iterations: the number of evaluation iterations

    Returns:
    model: the model
    train_losses: the train losses
    evaluation_losses: the evaluation losses
    encoded_data_per_eval: the encoded data
    """

    device = "cuda" if torch.cuda.is_available() else "cpu"

    model = model.to(device)

    trainloader = DataLoader(train_set, batch_size=batch_size, shuffle=True, num_workers=8)
    testloader = DataLoader(test_set, batch_size=batch_size, shuffle=False, num_workers=8)

    params_to_train = filter(lambda p: p.requires_grad, model.parameters())
    optimizer = torch.optim.AdamW(params_to_train, lr=0.0001, weight_decay=0.001)

    train_loss = []
    evaluation_loss = []

    encoded_data_per_eval = []
    train_losses = []
    evaluation_losses = []

    pbar = tqdm(range(training_iterations))

    train = True

    step_counter = 0
    while train:

        for images in trainloader:

            images = images.to(device)

            enc, dec, kl_loss = model(images)

            reconstruction_loss = torch.sum((dec - images)**2) / len(images)

            loss = reconstruction_loss + kl_weight * kl_loss

            train_loss.append(loss.item())

            loss.backward()
            optimizer.step()
            optimizer.zero_grad()

            if step_counter % evaluation_iterations == 0:

                model.eval()

                encoded_evaluations = []

                for images, labels in testloader:

                    images = images.to(device)

                    enc, dec, kl_loss = model(images)
                    reconstruction_loss = torch.sum((dec - images)**2) / len(images)

                    loss = reconstruction_loss + kl_weight * kl_loss

                    evaluation_loss.append(loss.item())

                    encoded, labels = enc.cpu().flatten(1), labels.reshape(-1,1)

                    encoded_evaluations.append(torch.cat((encoded, labels), axis=-1))


                encoded_data_per_eval.append(torch.concatenate(encoded_evaluations).detach())

                train_loss = np.mean(train_loss)
                evaluation_loss = np.mean(evaluation_loss)

                train_losses.append(train_loss)
                evaluation_losses.append(evaluation_loss)

                print("Training Loss", train_loss)
                print("Testing Loss", evaluation_loss)

                train_loss = []
                evaluation_loss = []

                model.train()

            step_counter += 1
            pbar.update(1)


            if step_counter >= training_iterations:
                print("Completed Training!")
                train = False
                break

    encoded_data_per_eval = [np.array(i) for i in encoded_data_per_eval]

    print("Final Training Loss", train_losses[-1])
    print("Final Evaluation Loss", evaluation_losses[-1])

    return model, train_losses, evaluation_losses, encoded_data_per_eval

model = VAE(in_channels=1)
model.encoder.load_state_dict(torch.load("vae18_encoder"+str(train_set_pct*100)+"_c.pt", weights_only=True))

def disable_update(module):
    for param in module.parameters():
        param.requires_grad_(False)

kl_weight = 0.5
train_set = ImageLoaderDataset("/content/CellData/OCT/train/NORMAL", transform=train_transform)
test_set = ImageFolder("/content/CellData/OCT/test", transform=val_transform)
batch_size = 64
training_iterations = 5000
evaluation_iterations = 500

model, train_losses, evaluation_losses, encoded_data_per_eval = train(model,
                                                                      kl_weight,
                                                                      train_set,
                                                                      test_set,
                                                                      batch_size,
                                                                      training_iterations,
                                                                      evaluation_iterations)
# Out:
#   0%|          | 0/5000 [00:00<?, ?it/s]
# Training Loss 21178.88671875
# Testing Loss 18006.6103515625
# Training Loss 2183.0979868164063
# Testing Loss 1676.812370300293
# Training Loss 909.1789603271484
# Testing Loss 1292.4962272644043
# Training Loss 716.7331166992187
# Testing Loss 1130.2367630004883
# Training Loss 626.6709763183594
# Testing Loss 1050.3901100158691
# Training Loss 563.878458618164
# Testing Loss 966.7925415039062
# Training Loss 520.2892044067382
# Testing Loss 922.7562255859375
# Training Loss 489.3782342529297
# Testing Loss 884.9821758270264
# Training Loss 463.09695941162107
# Testing Loss 864.4041919708252
# Training Loss 438.4113837280273
# Testing Loss 823.195405960083
# Completed Training!
# Final Training Loss 438.4113837280273
# Final Evaluation Loss 823.195405960083

# %% [markdown]
# I saved the state_dict each time.

# %%
torch.save(model.state_dict(), "vae18_"+ str(train_set_pct*100)+"_c.pt")

# %% [markdown]
# ### Plotting the Encoder Embeddings

# %% [markdown]
# To visualize the probabilistic latent space, I plotted the encoder embeddings using TSNE and seaborn, dimension-compression and data visualization tools.
#
# I produced a scatterplot which is colored by retinal disease condition. I also saved that figure to my computer.

# %%
encoded = encoded_data_per_eval[-1]
encoded_images, all_labels = encoded[:, :-1], encoded[:, -1]

tsne = TSNE(n_components=2)
tsne_out = tsne.fit_transform(encoded_images)
df = pd.DataFrame(tsne_out, columns=["Feature1", "Feature2"])
df["Label"] = all_labels
df["Label"] = df["Label"].map(data_classes)

sns.scatterplot(data=df, x="Feature1", y="Feature2", hue="Label", palette="Set1")

plt.title("Latent Space of Variational Autoencoder with encoder trained on " + str(int(train_set_pct*100)) +"% of the data")
plt.savefig("vae18_" + str(train_set_pct*100) +"clusterplot.jpeg")
plt.show()

# %% [markdown]
# # Checking the Quality of Clusters

# %% [markdown]
# First, in addition to my visual check of the clusters, I wanted to check the quality of clustering using the silhouette score.
#
# I calculated the silhouette score (SS) for each comparison of normal and each of the three conditions (DME, DRUSEN, and CNV).
#
# To explain briefly what the silhouette score is, it is a number ranging between -1 and 1 where more negative values indicate worse clustering, 0 indicates an overlap, and more positive values indicate better clustering.
#
# Here’s the formula:
# s(i) = (b(i) - a(i))/max (a(i), b(i))
#
# a(i) = avg distance of an observation to other points in the cluster
#
# b(i) avg distance of an observation to other points in the nearest cluster.
#
# I am following the above formula and averaging it for each point for each class to get the overall silhouette score.

# %%
from sklearn.metrics import silhouette_score

encoded_images, all_labels = encoded[:, :-1], encoded[:, -1]

cnv_df = df.loc[(df.loc[:, "Label"] == "CNV") | (df.loc[:, "Label"] == "NORMAL")]
dme_df = df.loc[(df.loc[:, "Label"] == "DME") | (df.loc[:, "Label"] == "NORMAL")]
drusen_df = df.loc[(df.loc[:, "Label"] == "DRUSEN") | (df.loc[:, "Label"] == "NORMAL")]

cnv_normal_images = cnv_df.loc[:, ["Feature1", "Feature2"]].values
dme_normal_images = dme_df.loc[:, ["Feature1", "Feature2"]].values
drusen_normal_images = drusen_df.loc[:, ["Feature1", "Feature2"]].values
label = np.array([0 for _ in range(250)] + [1 for _ in range(250)])

print("CNV-NORMAL SS = " + str(silhouette_score(cnv_normal_images, label)))
print("DME-NORMAL SS = " + str(silhouette_score(dme_normal_images, label)))
print("DRUSEN-NORMAL SS = " + str(silhouette_score(drusen_normal_images, label)))
# Out:
# CNV-NORMAL SS = 0.6126438
# DME-NORMAL SS = 0.46900672
# DRUSEN-NORMAL SS = 0.083952874

# %% [markdown]
# # Finding the % of class detected as anomaly

# %% [markdown]
# First, I used the describe() function to see what the mean and standard deviation for the two features plotted was (for the normal images) as I need to use those values to compute the z score later.

# %%
df.loc[df.loc[:,"Label"]=="NORMAL"].describe()
# Out:
#          Feature1    Feature2
# count  250.000000  250.000000
# mean   -11.587292    5.631243
# std      7.860469    8.452206
# min    -32.394825  -19.496063
# 25%    -16.754091    0.058443
# 50%    -10.659488    6.898198
# 75%     -5.937481   12.150325
# max      7.748537   20.984034

# %% [markdown]
# Here are the values I got as per the last time I ran this notebook.

# %%
f1mean = -9.543728
f1std = 8.697855
f2mean = -15.513106
f2std = 8.352103

# %% [markdown]
# I defined the function that computes the 2D z score given a data frame.

# %%
def twoDzScore(df):
    """
    Calculates the 2D z score given a data frame (using the previously found normal means and standard deviations
    as the default normal values)
    """
    z_scores = []
    for idx, row in df.iterrows():
      f1 = row["Feature1"]
      f2 = row["Feature2"]
      z = (((f1 - f1mean)/f1std)**2 +((f2 - f2mean)/f2std)**2)**0.5
      z_scores.append(z)
    df["z_score"] = z_scores
    return df

# %% [markdown]
# Using the threshold of three standard deviations away from the normal mean as an anomaly, I calculated how many of each of the retinal diseased OCT images were correctly flagged as anomalies with this method.

# %%
cnvData = df.loc[df.loc[:,"Label"]=="CNV"].copy()
cnvData = twoDzScore(cnvData)
print((cnvData["z_score"] > 3).sum()/len(cnvData))

dmeData = df.loc[df.loc[:,"Label"]=="DME"].copy()
dmeData = twoDzScore(dmeData)
print((dmeData["z_score"] > 3).sum()/len(dmeData))

drusenData = df.loc[df.loc[:,"Label"]=="DRUSEN"].copy()
drusenData = twoDzScore(drusenData)
print((drusenData["z_score"] > 3).sum()/len(drusenData))
# Out:
# 0.628
# 0.932
# 0.264

# %%
normalData = df.loc[df.loc[:,"Label"]=="NORMAL"].copy()
normalData = twoDzScore(normalData)
print((normalData["z_score"] > 3).sum()/len(normalData))
# Out:
# 0.452
